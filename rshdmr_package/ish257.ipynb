# %%
from hdmr import rshdmr
# %matplotlib notebook

# %%
ishigami_256 = rshdmr('ish257.csv', 
              poly_order=10,
              gmdh_ref_functions = 'linear-cov',
              cutoff = 0.00,
              regression_type='ard' 
              )
ishigami_256.auto()
# Out:
# ['X1', 'X2', 'X3']
# X1 : min -3.14159 max 3.14159
# X2 : min -3.14159 max 3.14159
# X3 : min -3.14159 max 3.14159
# ...
# train layer0 in 5.59 sec
# train layer1 in 1.61 sec
# train layer2 in 1.44 sec
# train layer3 in 1.42 sec
# train layer4 in 1.41 sec
# train layer5 in 1.59 sec
# train layer6 in 1.54 sec
# train layer7 in 1.42 sec
# train layer8 in 1.47 sec
# train layer9 in 1.42 sec
# train layer10 in 1.41 sec
# train layer11 in 1.41 sec
# train layer12 in 1.48 sec
# train layer13 in 1.59 sec
# train layer14 in 1.44 sec
# train layer15 in 1.43 sec
# train layer16 in 1.40 sec
# train layer17 in 1.41 sec
# train layer18 in 1.40 sec
# train layer19 in 1.42 sec
# ...
# total selected coeffs 77
# total zero coeffs 63
# ...
# X1 : 0.313721329175
# X2 : 0.442223974584
# X1_X3 : 0.244054696241
# <img src="data:image/png;base64,..." width="640">

# %%
X = [0.959957089,0.136110303,0.69662909,0.998204862,0.095825239,0.633104077,0.017528355,0.793882793]
year1.evaluate_func(X)

# %%
ishigami_256.print_sobol_indices()
ishigami_256.plot_hdmr()

# %%
ishigami_256.print_sobol_indices()
# Out:
# X1 : 0.313721329175
# X2 : 0.442223974584
# X1_X3 : 0.244054696241

# %%
ishigami_256.plot_hdmr()
# Out:
# <img src="data:image/png;base64,..." width="640">
