# %%
import veneer
import os
import pandas as pd
import numpy as np
import sys
#sys.path.append('..\\..\\..\\dsed-py\\dsed-py\\dsed')
#from dsed.testing.preprocessors import *
import dsed
from dsed import preprocessors
#from dsed.preprocessors import raster_path
# Out:
# gully Dynamic_SedNet.Parameterisation.Models.GullyParameterisationModel
# usle Dynamic_SedNet.Parameterisation.Models.CoverTimeSeries_SpatialPreprocessorModel

# %%
v = veneer.Veneer()

# %%
veneer.general.PRINT_SCRIPTS=False

# %%
#UNUSED=[
#    'Path_lsRaster'
#]

# %%
parameters = {
    'Path_klsRaster':'"D:/MW/Ram_USLE/athena_data/mw_kfact.asc"',
    'Path_lsRaster':'"D:/MW/Ram_USLE/athena_data/mw_sfact.asc"',
    'Path_ClayPercRaster':'"D:/MW/Ram_USLE/athena_data/mw_cssurf.asc"',
    'Path_Intersected':'"D:/MW/spatial_RC7/ExportedCatchments-FUs Intersection.shp"',
    'Path_CFactorDirectory':'"D:/MW/Ram_USLE/skip"',
    'DatePattern':'"xxxyyyymm"',
    'FUtoParameterise':['Grazing Open','Grazing Forested','Conservation','Forestry'],
    'Path_TSOutputDirectory':'"D:/MW/Ram_USLE/veneer_outputs"',
    'useInternalIntersectedPolys':False,
    'updateModels':False,
    'useCombinedKLS':False,
    'maxThreads':6,
    'TemperalCoverType':'"TimeSeries"',
    'AnalysisTimeStep':'"Seasonal"'
}

# %%
preprocessor = preprocessors.run_usle

# %%
UNUSED = []

# %%
type(parameters['FUtoParameterise'])==list
# Out:
# True

# %%
type(5),type(5.0),type('5')
# Out:
# (int, float, str)

# %%
defaults = preprocessors.usle_default_params(v)
{k:v for k,v in defaults.items() if v is None and not k in parameters and not k in UNUSED}
# Out:
# # Generated Script
# import Dynamic_SedNet.Parameterisation.Models.CoverTimeSeries_SpatialPreprocessorModel
# import clr
# clr.AddReference('System.Core')
# import System
# import FlowMatters.Source.Veneer.RemoteScripting.ScriptHelpers as H
# clr.ImportExtensions(System.Linq)
# from TIME.Core.Metadata import ParameterAttribute
# result = []
# tmp = Dynamic_SedNet.Parameterisation.Models.CoverTimeSeries_SpatialPreprocessorModel()
# typeObject = tmp.GetType()
# for member in dir(tmp):
#   try:
#     if typeObject.GetMember(member)[0].IsDefined(ParameterAttribute,True):
#       result.append(member)
#   except: pass
#
# import Dynamic_SedNet.Parameterisation.Models.CoverTimeSeries_SpatialPreprocessorModel
# model = Dynamic_SedNet.Parameterisation.Models.CoverTimeSeries_SpatialPreprocessorModel()
# result = {}
#
# result["AnalysisTimeStep"]=model.AnalysisTimeStep
# result["ConstantCFactorValue"]=model.ConstantCFactorValue
# result["DatePattern"]=model.DatePattern
# result["FUtoParameterise"]=model.FUtoParameterise
# result["Path_CFactorDirectory"]=model.Path_CFactorDirectory
# result["Path_ClayPercRaster"]=model.Path_ClayPercRaster
# result["Path_Intersected"]=model.Path_Intersected
# result["Path_PercScaldRaster"]=model.Path_PercScaldRaster
# result["Path_StaticKLSCFile"]=model.Path_StaticKLSCFile
# result["Path_TSOutputDirectory"]=model.Path_TSOutputDirectory
# result["Path_klsRaster"]=model.Path_klsRaster
# result["Path_lsRaster"]=model.Path_lsRaster
# result["TemperalCoverType"]=model.TemperalCoverType
# result["defaultCovCFactVal"]=model.defaultCovCFactVal
# result["doParallel"]=model.doParallel
# result["maxThreads"]=model.maxThreads
# result["requiredEndDate"]=model.requiredEndDate
# result["requiredStartDate"]=model.requiredStartDate
# result["threshValidCovPerc"]=model.threshValidCovPerc
# result["updateModels"]=model.updateModels
# result["useCombinedKLS"]=model.useCombinedKLS
# result["useFuAverage"]=model.useFuAverage
# result["useInternalIntersectedPolys"]=model.useInternalIntersectedPolys
# {'Path_PercScaldRaster': None, 'Path_StaticKLSCFile': None}

# %%
#defaults
veneer.general.PRINT_SCRIPTS=False

# %%
veneer.general.PRINT_SCRIPTS=True
result = preprocessors.run_usle(v,**parameters)
# Out:
# # Generated Script
# import Dynamic_SedNet.Parameterisation.Models.CoverTimeSeries_SpatialPreprocessorModel
# import clr
# clr.AddReference('System.Core')
# import System
# import FlowMatters.Source.Veneer.RemoteScripting.ScriptHelpers as H
# clr.ImportExtensions(System.Linq)
# from TIME.Core.Metadata import OutputAttribute
# result = []
# tmp = Dynamic_SedNet.Parameterisation.Models.CoverTimeSeries_SpatialPreprocessorModel()
# typeObject = tmp.GetType()
# for member in dir(tmp):
#   try:
#     if typeObject.GetMember(member)[0].IsDefined(OutputAttribute,True):
#       result.append(member)
#   except: pass
#
# import Dynamic_SedNet.Parameterisation.Models.CoverTimeSeries_SpatialPreprocessorModel as CoverTimeSeries_SpatialPreprocessorModel
# import Dynamic_SedNet.Tools.ToolsModel as ToolsModel
#
# p = CoverTimeSeries_SpatialPreprocessorModel()
# p.Scenario = scenario
# p.CatPolys = scenario.GeographicData.IntersectedSCFUPolygons[1]
# p.FuPolys = scenario.GeographicData.IntersectedSCFUPolygons[1]
# p.DatePattern = "xxxyyyymm"
# p.FUtoParameterise = tuple(['Grazing Open', 'Grazing Forested', 'Conservation', 'Forestry'])
# p.useCombinedKLS = False
# p.useInternalIntersectedPolys = False
# p.Path_TSOutputDirectory = "D:/MW/Ram_USLE/veneer_outputs"
# p.Path_Intersected = "D:/MW/spatial_RC7/ExportedCatchments-FUs Intersection.shp"
# p.updateModels = False
# p.Path_CFactorDirectory = "D:/MW/Ram_USLE/skip"
# p.maxThreads = 6
# p.AnalysisTimeStep = "Seasonal"
# p.Path_lsRaster = "D:/MW/Ram_USLE/athena_data/mw_sfact.asc"
# p.TemperalCoverType = "TimeSeries"
# p.Path_klsRaster = "D:/MW/Ram_USLE/athena_data/mw_kfact.asc"
# p.Path_ClayPercRaster = "D:/MW/Ram_USLE/athena_data/mw_cssurf.asc"
# p.runTimeStep()
# result = {}
# result["ResultsTable"] = p.ResultsTable
# result["globalAverageResultsTable"] = p.globalAverageResultsTable

# %%
result
# Out:
# {'ResultsTable': [{'Area': 34080,
#    'Catchment_Name': 'SC #159',
#    'Cell_Count': 1136,
#    'FU_Name': 'Conservation',
#    'IntSCFU': 1155,
#    'Mean_CFact': 0.044213940659762,
#    'Mean_Fines': 28.8318661971831,
#    'Mean_KLS': 0.0388418133802819,
#    'Mean_KLSC': 0.00742073017087116,
#    'Mean_KLSC_Fines': 0.00207951094789348,
#    'Mean_LS': 4.84248309037853,
#    'Mean_Scald': 0,
#    'Time_Step': '1/09/1987'},
#   {'Area': 323250,
#    'Catchment_Name': 'SC #22',
#    'Cell_Count': 10775,
#    'FU_Name': 'Grazing Open',
#    'IntSCFU': 124,
#    'Mean_CFact': 0.0311912775014175,
#    'Mean_Fines': 35.2610672853828,
#    'Mean_KLS': 0.054857939675175,
#    'Mean_KLSC': 0.000553437882134062,
#    'Mean_KLSC_Fines': 0.000192038659967832,
#    'Mean_LS': 0.370254067891411,
#    'Mean_Scald': 0,
#    'Time_Step': '1/09/1987'},
#   {'Area': 86100,
#    'Catchment_Name': 'SC #138',
#    'Cell_Count': 2870,
#    'FU_Name': 'Grazing Open',
#    'IntSCFU': 1135,
#    'Mean_CFact': 0.0268161910563344,
#    'Mean_Fines': 28.3749128919861,
#    'Mean_KLS': 0.04017825783972,
#    'Mean_KLSC': 0.000236670618502621,
#    'Mean_KLSC_Fines': 6.69409571442954e-05,
#    'Mean_LS': 0.289990591979084,
#    'Mean_Scald': 0,
#    'Time_Step': '1/09/1987'},
#   {'Area': 78990,
#    'Catchment_Name': '',
#    'Cell_Count': 2633,
#    'FU_Name': '',
#    'IntSCFU': 153,
#    'Mean_CFact': 0.11759742371617,
#    'Mean_Fines': 47.1804025826054,
#    'Mean_KLS': 0.0716604633497898,
#    'Mean_KLSC': 0.00043320499337228,
#    'Mean_KLSC_Fines': 0.000206325394152072,
#    'Mean_LS': 0.0574320807178136,
#    'Mean_Scald': 0,
#    'Time_Step': '1/09/1987'},
#   {'Area': 35100,
#    'Catchment_Name': '',
#    'Cell_Count': 1170,
#    'FU_Name': '',
#    'IntSCFU': 186,
#    'Mean_CFact': 0.088477576420141,
#    'Mean_Fines': 43.3581196581197,
#    'Mean_KLS': 0.0649671794871785,
#    'Mean_KLSC': 0.000344094588268425,
#    'Mean_KLSC_Fines': 0.000168163440776155,
#    'Mean_LS': 0.0629450172478639,
#    'Mean_Scald': 0,
#    'Time_Step': '1/09/1987'},
#   {'Area': 154320,
#    'Catchment_Name': 'SC #158',
#    'Cell_Count': 5144,
#    'FU_Name': 'Grazing Open',
#    'IntSCFU': 931,
#    'Mean_CFact': 0.016096333812156,
#    'Mean_Fines': 41.2185069984448,
#    'Mean_KLS': 0.0589096228615921,
#    'Mean_KLSC': 0.000330655518047063,
#    'Mean_KLSC_Fines': 0.000114151669502699,
#    'Mean_LS': 0.654198085075814,
#    'Mean_Scald': 0,
#    'Time_Step': '1/09/1987'},
#   {'Area': 822900,
#    'Catchment_Name': 'SC #10',
#    'Cell_Count': 27430,
#    'FU_Name': 'Grazing Forested',
#    'IntSCFU': 15,
#    'Mean_CFact': 0.0682325181621899,
#    'Mean_Fines': 35.4367845424717,
#    'Mean_KLS': 0.0553502624863332,
#    'Mean_KLSC': 0.00203227439354196,
#    'Mean_KLSC_Fines': 0.000822676031470482,
#    'Mean_LS': 0.560804619941312,
#    'Mean_Scald': 0,
#    'Time_Step': '1/09/1987'},
#   {'Area': 20220,
#    'Catchment_Name': '',
#    'Cell_Count': 674,
#    'FU_Name': '',
#    'IntSCFU': 219,
#    'Mean_CFact': 0.0389283556077983,
#    'Mean_Fines': 32.8946587537092,
#    'Mean_KLS': 0.0497103857566768,
#    'Mean_KLSC': 0.000110284881173983,
#    'Mean_KLSC_Fines': 3.61550957262145e-05,
#    'Mean_LS': 0.0569999099999996,
#    'Mean_Scald': 0,
#    'Time_Step': '1/09/1987'},
#   {'Area': 204960,
#    'Catchment_Name': '',
#    'Cell_Count': 6832,
#    'FU_Name': '',
#    'IntSCFU': 651,
#    'Mean_CFact': 0.0987924131144528,
#    'Mean_Fines': 44.7757611241218,
#    'Mean_KLS': 0.0700408518735334,
#    'Mean_KLSC': 0.000412515917137505,
#    'Mean_KLSC_Fines': 0.000209578293007581,
#    'Mean_LS': 0.0570273759967815,
#    'Mean_Scald': 0,
#    'Time_Step': '1/09/1987'},
#   {'Area': 35490,
#    'Catchment_Name': 'SC #46',
#    'Cell_Count': 1183,
#    'FU_Name': 'Forestry',
#    'IntSCFU': 252,
#    'Mean_CFact': 0.0264533659780204,
#    'Mean_Fines': 30.843617920541,
#    'Mean_KLS': 0.0474848689771766,
#    'Mean_KLSC': 0.000440122473704606,
#    'Mean_KLSC_Fines': 0.000160983465333917,
#    'Mean_LS': 0.230199367083686,
#    'Mean_Scald': 0,
#    'Time_Step': '1/09/1987'},
#   {'Area': 14160,
#    'Catchment_Name': 'SC #117',
#    'Cell_Count': 472,
#    'FU_Name': 'Grazing Open',
#    'IntSCFU': 1063,
#    'Mean_CFact': 0.058444885462049,
#    'Mean_Fines': 49.9809322033898,
#    'Mean_KLS': 0.0616379237288134,
#    'Mean_KLSC': 0.000199152840139517,
#    'Mean_KLSC_Fines': 0.000102008761246131,
#    'Mean_LS': 0.0569999099999993,
#    'Mean_Scald': 0,
#    'Time_Step': '1/09/1987'},
#   {'Area': 57180,
#    'Catchment_Name': 'SC #137',
#    'Cell_Count': 1906,
#    'FU_Name': 'Grazing Open',
#    'IntSCFU': 1183,
#    'Mean_CFact': 0.0409914506907142,
#    'Mean_Fines': 29.9118572927597,
#    'Mean_KLS': 0.0467426023084991,
#    'Mean_KLSC': 0.000193896256600199,
#    'Mean_KLSC_Fines': 5.70867629505481e-05,
#    'Mean_LS': 0.143328638819519,
#    'Mean_Scald': 0,
#    'Time_Step': '1/09/1987'},
#   {'Area': 4500,
#    'Catchment_Name': '',
#    'Cell_Count': 150,
#    'FU_Name': '',
#    'IntSCFU': 1073,
#    'Mean_CFact': 0.0820991210453212,
#    'Mean_Fines': 49,
#    'Mean_KLS': 0.0700666666666668,
#    'Mean_KLSC': 0.000333295930606266,
#    'Mean_KLSC_Fines': 0.000167752675489173,
#    'Mean_LS': 0.05699991,
#    'Mean_Scald': 0,
#    'Time_Step': '1/09/1987'},
#   {'Area': 3390,
#    'Catchment_Name': 'SC #132',
#    'Cell_Count': 113,
#    'FU_Name': 'Conservation',
#    'IntSCFU': 1139,
#    'Mean_CFact': 0.0661877513475782,
#    'Mean_Fines': 29.2300884955752,
#    'Mean_KLS': 0.0462176991150443,
#    'Mean_KLSC': 0.000213688451283695,
#    'Mean_KLSC_Fines': 5.67648073757283e-05,
#    'Mean_LS': 0.0695318683185841,
#    'Mean_Scald': 0,
#    'Time_Step': '1/09/1987'},
#   {'Area': 21540,
#    'Catchment_Name': 'SC #130',
#    'Cell_Count': 718,
#    'FU_Name': 'Conservation',
#    'IntSCFU': 1205,
#    'Mean_CFact': 0.0521369483017662,
#    'Mean_Fines': 34.4456824512535,
#    'Mean_KLS': 0.0583903899721451,
#    'Mean_KLSC': 0.000173880021057558,
#    'Mean_KLSC_Fines': 5.88519378605442e-05,
#    'Mean_LS': 0.0569999099999997,
#    'Mean_Scald': 0,
#    'Time_Step': '1/09/1987'},
#   {'Area': 463200,
#    'Catchment_Name': 'SC #2',
#    'Cell_Count': 15440,
#    'FU_Name': 'Grazing Forested',
#    'IntSCFU': 4,
#    'Mean_CFact': 0.078216851283006,
#    'Mean_Fines': 33.4312176165803,
#    'Mean_KLS': 0.0514774935233174,
#    'Mean_KLSC': 0.00160097824664208,
#    'Mean_KLSC_Fines': 0.000479794497655175,
#    'Mean_LS': 0.482812180610092,
#    'Mean_Scald': 0,
#    'Time_Step': '1/09/1987'},
#   {'Area': 1320,
#    'Catchment_Name': 'SC #26',
#    'Cell_Count': 44,
#    'FU_Name': 'Grazing Forested',
#    'IntSCFU': 380,
#    'Mean_CFact': 0.0225334985033524,
#    'Mean_Fines': 48.6363636363636,
#    'Mean_KLS': 0.0748045454545455,
#    'Mean_KLSC': 9.50877421795523e-05,
#    'Mean_KLSC_Fines': 4.68378395271389e-05,
#    'Mean_LS': 0.05699991,
#    'Mean_Scald': 0,
#    'Time_Step': '1/09/1987'},
#   {'Area': 9060,
#    'Catchment_Name': '',
#    'Cell_Count': 302,
#    'FU_Name': '',
#    'IntSCFU': 413,
#    'Mean_CFact': 0.106870622434252,
#    'Mean_Fines': 32.0099337748344,
#    'Mean_KLS': 0.0592198675496685,
#    'Mean_KLSC': 0.000359352824087825,
#    'Mean_KLSC_Fines': 0.000114687922400837,
#    'Mean_LS': 0.0569999099999999,
#    'Mean_Scald': 0,
#    'Time_Step': '1/09/1987'},
#   {'Area': 2880,
#    'Catchment_Name': 'SC #85',
#    'Cell_Count': 96,
#    'FU_Name': 'Grazing Open',
#    'IntSCFU': 296,
#    'Mean_CFact': 0.0436277380989244,
#    'Mean_Fines': 28,
#    'Mean_KLS': 0.0434875,
#    'Mean_KLSC': 0.0106829461121618,
#    'Mean_KLSC_Fines': 0.00299122491140529,
#    'Mean_LS': 4.63017914041667,
#    'Mean_Scald': 0,
#    'Time_Step': '1/09/1987'},
#   {'Area': 1860,
#    'Catchment_Name': '',
#    'Cell_Count': 62,
#    'FU_Name': '',
#    'IntSCFU': 446,
#    'Mean_CFact': 0.102876589663567,
#    'Mean_Fines': 40.4032258064516,
#    'Mean_KLS': 0.0583370967741936,
#    'Mean_KLSC': 0.0045139047582256,
#    'Mean_KLSC_Fines': 0.00199021706438777,
#    'Mean_LS': 0.928636920967742,
#    'Mean_Scald': 0,
#    'Time_Step': '1/09/1987'},
#   {'Area': 233100,
#    'Catchment_Name': '',
#    'Cell_Count': 7770,
#    'FU_Name': '',
#    'IntSCFU': 1067,
#    'Mean_CFact': 0.104757606740406,
#    'Mean_Fines': 29.8808236808237,
#    'Mean_KLS': 0.0387815186615206,
#    'Mean_KLSC': 0.000501469234364097,
#    'Mean_KLSC_Fines': 0.000137492735933828,
#    'Mean_LS': 0.148020211396379,
#    'Mean_Scald': 0,
#    'Time_Step': '1/09/1987'},
#   {'Area': 33870,
#    'Catchment_Name': '',
#    'Cell_Count': 1129,
#    'FU_Name': '',
#    'IntSCFU': 479,
#    'Mean_CFact': 0.0443324691738085,
#    'Mean_Fines': 49.8379096545616,
#    'Mean_KLS': 0.0513366696191308,
#    'Mean_KLSC': 0.000126879278351866,
#    'Mean_KLSC_Fines': 6.44092638068335e-05,
#    'Mean_LS': 0.0569999100000005,
#    'Mean_Scald': 0,
#    'Time_Step': '1/09/1987'},
#   {'Area': 56280,
#    'Catchment_Name': 'SC #155',
#    'Cell_Count': 1876,
#    'FU_Name': 'Forestry',
#    'IntSCFU': 363,
#    'Mean_CFact': 0.0373872527756752,
#    'Mean_Fines': 27.9594882729211,
#    'Mean_KLS': 0.0370886993603402,
#    'Mean_KLSC': 0.00417181096744021,
#    'Mean_KLSC_Fines': 0.00116641426706721,
#    'Mean_LS': 2.96792173486141,
#    'Mean_Scald': 0,
#    'Time_Step': '1/09/1987'},
#   {'Area': 60,
#    'Catchment_Name': 'SC #30',
#    'Cell_Count': 2,
#    'FU_Name': 'Conservation',
#    'IntSCFU': 512,
#    'Mean_CFact': 0.0151304681785405,
#    'Mean_Fines': 34,
#    'Mean_KLS': 0.0534,
#    'Mean_KLSC': 4.60540463248114e-05,
#    'Mean_KLSC_Fines': 1.56583757504359e-05,
#    'Mean_LS': 0.05699991,
#    'Mean_Scald': 0,
#    'Time_Step': '1/09/1987'},
#   {'Area': 25050,
#    'Catchment_Name': '',
#    'Cell_Count': 835,
#    'FU_Name': '',
#    'IntSCFU': 545,
#    'Mean_CFact': 0.0871012472212984,
#    'Mean_Fines': 48.7904191616766,
#    'Mean_KLS': 0.0678017964071852,
#    'Mean_KLSC': 0.000425974169460641,
#    'Mean_KLSC_Fines': 0.000214966377369377,
#    'Mean_LS': 0.0907474721556893,
#    'Mean_Scald': 0,
#    'Time_Step': '1/09/1987'},
#   {'Area': 51360,
#    'Catchment_Name': 'SC #90172',
#    'Cell_Count': 1712,
#    'FU_Name': 'Grazing Forested',
#    'IntSCFU': 578,
#    'Mean_CFact': 0.028344541826997,
#    'Mean_Fines': 45.6349299065421,
#    'Mean_KLS': 0.0584585864485987,
#    'Mean_KLSC': 0.00185166862303556,
#    'Mean_KLSC_Fines': 0.000823275034592237,
#    'Mean_LS': 1.10955724208528,
#    'Mean_Scald': 0,
#    'Time_Step': '1/09/1987'},
#   {'Area': 81480,
#    'Catchment_Name': '',
#    'Cell_Count': 2716,
#    'FU_Name': '',
#    'IntSCFU': 611,
#    'Mean_CFact': 0.0831380156816953,
#    'Mean_Fines': 45.5419734904271,
#    'Mean_KLS': 0.0672615611192921,
#    'Mean_KLSC': 0.00167611687317183,
#    'Mean_KLSC_Fines': 0.000814520839999289,
#    'Mean_LS': 0.560075647882927,
#    'Mean_Scald': 0,
#    'Time_Step': '1/09/1987'},
#   {'Area': 510,
#    'Catchment_Name': '',
#    'Cell_Count': 17,
#    'FU_Name': '',
#    'IntSCFU': 644,
#    'Mean_CFact': 0.0890483465045691,
#    'Mean_Fines': 60,
#    'Mean_KLS': 0.0866352941176471,
#    'Mean_KLSC': 0.000447914511765864,
#    'Mean_KLSC_Fines': 0.000276697381343394,
#    'Mean_LS': 0.05699991,
#    'Mean_Scald': 0,
#    'Time_Step': '1/09/1987'},
#   {'Area': 87930,
#    'Catchment_Name': 'SC #67',
#    'Cell_Count': 2931,
#    'FU_Name': 'Grazing Forested',
#    'IntSCFU': 677,
#    'Mean_CFact': 0.0199587621843027,
#    'Mean_Fines': 65.0655066530194,
#    'Mean_KLS': 0.0664518935516903,
#    'Mean_KLSC': 0.00170663408010059,
#    'Mean_KLSC_Fines': 0.00113109291863478,
#    'Mean_LS': 1.41995160602522,
#    'Mean_Scald': 0,
#    'Time_Step': '1/09/1987'},
#   {'Area': 5640,
#    'Catchment_Name': 'SC #128',
#    'Cell_Count': 188,
#    'FU_Name': 'Grazing Open',
#    'IntSCFU': 1175,
#    'Mean_CFact': 0.0526164794746945,
#    'Mean_Fines': 47.3723404255319,
#    'Mean_KLS': 0.0620734042553193,
#    'Mean_KLSC': 0.000189853462368455,
#    'Mean_KLSC_Fines': 8.70330932249202e-05,
#    'Mean_LS': 0.0583372082978724,
#    'Mean_Scald': 0,
#    'Time_Step': '1/09/1987'},
#   {'Area': 2400,
#    'Catchment_Name': '',
#    'Cell_Count': 80,
#    'FU_Name': '',
#    'IntSCFU': 743,
#    'Mean_CFact': 0.0444544147224165,
#    'Mean_Fines': 50.625,
#    'Mean_KLS': 0.06349375,
#    'Mean_KLSC': 0.00258989129407967,
#    'Mean_KLSC_Fines': 0.00132051997024853,
#    'Mean_LS': 0.955653092875,
#    'Mean_Scald': 0,
#    'Time_Step': '1/09/1987'},
#   {'Area': 1140,
#    'Catchment_Name': '',
#    'Cell_Count': 38,
#    'FU_Name': '',
#    'IntSCFU': 776,
#    'Mean_CFact': 0.0310448018196774,
#    'Mean_Fines': 33.2105263157895,
#    'Mean_KLS': 0.0598631578947368,
#    'Mean_KLSC': 0.00135480013759912,
#    'Mean_KLSC_Fines': 0.000481496393176494,
#    'Mean_LS': 0.736805378947368,
#    'Mean_Scald': 0,
#    'Time_Step': '1/09/1987'},
#   {'Area': 747540,
#    'Catchment_Name': 'SC #90175',
#    'Cell_Count': 24918,
#    'FU_Name': 'Conservation',
#    'IntSCFU': 594,
#    'Mean_CFact': 0.0383587163556767,
#    'Mean_Fines': 47.1050964812586,
#    'Mean_KLS': 0.0635677927602521,
#    'Mean_KLSC': 0.00954619017855226,
#    'Mean_KLSC_Fines': 0.00469789106896788,
#    'Mean_LS': 3.88170767069224,
#    'Mean_Scald': 0,
#    'Time_Step': '1/09/1987'},
#   {'Area': 28560,
#    'Catchment_Name': 'SC #154',
#    'Cell_Count': 952,
#    'FU_Name': 'Grazing Forested',
#    'IntSCFU': 842,
#    'Mean_CFact': 0.0151794386412283,
#    'Mean_Fines': 43.6890756302521,
#    'Mean_KLS': 0.0607732142857134,
#    'Mean_KLSC': 0.00040866451653301,
#    'Mean_KLSC_Fines': 0.000250576769706603,
#    'Mean_LS': 0.590030236607118,
#    'Mean_Scald': 0,
#    'Time_Step': '1/09/1987'},
#   {'Area': 266160,
#    'Catchment_Name': 'SC #120',
#    'Cell_Count': 8872,
#    'FU_Name': 'Grazing Forested',
#    'IntSCFU': 875,
#    'Mean_CFact': 0.0240649005620803,
#    'Mean_Fines': 31.595130748422,
#    'Mean_KLS': 0.0462181582506713,
#    'Mean_KLSC': 0.00230395771399088,
#    'Mean_KLSC_Fines': 0.000696116852244305,
#    'Mean_LS': 2.4857838439969,
#    'Mean_Scald': 0,
#    'Time_Step': '1/09/1987'},
#   {'Area': 1290,
#    'Catchment_Name': '',
#    'Cell_Count': 43,
#    'FU_Name': '',
#    'IntSCFU': 908,
#    'Mean_CFact': 0.0765968662968209,
#    'Mean_Fines': 39.4418604651163,
#    'Mean_KLS': 0.0706744186046511,
#    'Mean_KLSC': 0.00885975867857537,
#    'Mean_KLSC_Fines': 0.00354244755010554,
#    'Mean_LS': 1.55676310837209,
#    'Mean_Scald': 0,
#    'Time_Step': '1/09/1987'},
#   {'Area': 2250,
#    'Catchment_Name': 'SC #164',
#    'Cell_Count': 75,
#    'FU_Name': 'Conservation',
#    'IntSCFU': 941,
#    'Mean_CFact': 0.0595893928036094,
#    'Mean_Fines': 31.6666666666667,
#    'Mean_KLS': 0.0603760000000001,
#    'Mean_KLSC': 0.000210203805469041,
#    'Mean_KLSC_Fines': 6.74496698535029e-05,
#    'Mean_LS': 0.05699991,
#    'Mean_Scald': 0,
#    'Time_Step': '1/09/1987'},
#   {'Area': 8340,
#    'Catchment_Name': '',
#    'Cell_Count': 278,
#    'FU_Name': '',
#    'IntSCFU': 974,
#    'Mean_CFact': 0.0242863312437326,
#    'Mean_Fines': 69,
#    'Mean_KLS': 0.0915999999999998,
#    'Mean_KLSC': 0.000126803592473262,
#    'Mean_KLSC_Fines': 8.74944788065508e-05,
#    'Mean_LS': 0.05699991,
#    'Mean_Scald': 0,
#    'Time_Step': '1/09/1987'},
#   {'Area': 20790,
#    'Catchment_Name': '',
#    'Cell_Count': 693,
#    'FU_Name': '',
#    'IntSCFU': 1007,
#    'Mean_CFact': 0.119785466065434,
#    'Mean_Fines': 39.2886002886003,
#    'Mean_KLS': 0.0703105339105337,
#    'Mean_KLSC': 0.000616665473817302,
#    'Mean_KLSC_Fines': 0.000220724071059872,
#    'Mean_LS': 0.0764742269841265,
#    'Mean_Scald': 0,
#    'Time_Step': '1/09/1987'},
#   {'Area': 5400,
#    'Catchment_Name': 'SC #117',
#    'Cell_Count': 180,
#    'FU_Name': 'Grazing Forested',
#    'IntSCFU': 1056,
#    'Mean_CFact': 0.0445436275253693,
#    'Mean_Fines': 48.1944444444444,
#    'Mean_KLS': 0.0633283333333334,
#    'Mean_KLSC': 0.000152769981179278,
#    'Mean_KLSC_Fines': 7.71852114447911e-05,
#    'Mean_LS': 0.05699991,
#    'Mean_Scald': 0,
#    'Time_Step': '1/09/1987'},
#   {'Area': 303180,
#    'Catchment_Name': 'SC #134',
#    'Cell_Count': 10106,
#    'FU_Name': 'Grazing Open',
#    'IntSCFU': 1122,
#    'Mean_CFact': 0.0401389821479162,
#    'Mean_Fines': 37.4118345537305,
#    'Mean_KLS': 0.0547985157332285,
#    'Mean_KLSC': 0.00027772488009238,
#    'Mean_KLSC_Fines': 0.000103712354456084,
#    'Mean_LS': 0.150790948679982,
#    'Mean_Scald': 0,
#    'Time_Step': '1/09/1987'},
#   {'Area': 2910,
#    'Catchment_Name': '',
#    'Cell_Count': 97,
#    'FU_Name': '',
#    'IntSCFU': 297,
#    'Mean_CFact': 0.0900160866530286,
#    'Mean_Fines': 18.6494845360825,
#    'Mean_KLS': 0.0350917525773196,
#    'Mean_KLSC': 0.000694395842888567,
#    'Mean_KLSC_Fines': 0.000122529726507773,
#    'Mean_LS': 0.215075839072165,
#    'Mean_Scald': 0,
#    'Time_Step': '1/09/1987'},
#   {'Area': 14730,
#    'Catchment_Name': '',
#    'Cell_Count': 491,
#    'FU_Name': '',
#    'IntSCFU': 1254,
#    'Mean_CFact': 0.0146421300960504,
#    'Mean_Fines': 20,
#    'Mean_KLS': 0.0438,
#    'Mean_KLSC': 3.65554842785225e-05,
#    'Mean_KLSC_Fines': 7.31109685570451e-06,
#    'Mean_LS': 0.0569999099999993,
#    'Mean_Scald': 0,
#    'Time_Step': '1/09/1987'},
#   {'Area': 117060,
#    'Catchment_Name': 'SC #90197',
#    'Cell_Count': 3902,
#    'FU_Name': 'Grazing Open',
#    'IntSCFU': 1279,
#    'Mean_CFact': 0.0433340133967375,
#    'Mean_Fines': 26.1007121424911,
#    'Mean_KLS': 0.0455984853921065,
#    'Mean_KLSC': 0.000348979883267097,
#    'Mean_KLSC_Fines': 0.000103409611887771,
#    'Mean_LS': 0.147458628498205,
#    'Mean_Scald': 0,
#    'Time_Step': '1/09/1987'},
#   {'Area': 256170,
#    'Catchment_Name': '',
#    'Cell_Count': 8539,
#    'FU_Name': '',
#    'IntSCFU': 346,
#    'Mean_CFact': 0.0451748483990006,
#    'Mean_Fines': 44.5317952921888,
#    'Mean_KLS': 0.0561702189952043,
#    'Mean_KLSC': 0.00017752232006793,
#    'Mean_KLSC_Fines': 8.81354425837183e-05,
#    'Mean_LS': 0.0691651467373238,
#    'Mean_Scald': 0,
#    'Time_Step': '1/09/1987'},
#   {'Area': 948540,
#    'Catchment_Name': 'SC #49',
#    'Cell_Count': 31618,
#    'FU_Name': 'Grazing Open',
#    'IntSCFU': 157,
#    'Mean_CFact': 0.0244736440500197,
#    'Mean_Fines': 36.7185780251755,
#    'Mean_KLS': 0.055000607249036,
#    'Mean_KLSC': 0.000595792210924285,
#    'Mean_KLSC_Fines': 0.000231074283206085,
#    'Mean_LS': 0.4297227686334,
#    'Mean_Scald': 0,
#    'Time_Step': '1/09/1987'},
#   {'Area': 1440,
#    'Catchment_Name': '',
#    'Cell_Count': 48,
#    'FU_Name': '',
#    'IntSCFU': 1003,
#    'Mean_CFact': 0.0501983924962891,
#    'Mean_Fines': 58.6875,
#    'Mean_KLS': 0.0687458333333333,
#    'Mean_KLSC': 0.00167285633581391,
#    'Mean_KLSC_Fines': 0.000744624577420232,
#    'Mean_LS': 0.455457583958333,
#    'Mean_Scald': 0,
#    'Time_Step': '1/09/1987'},
#   {'Area': 45600,
#    'Catchment_Name': '',
#    'Cell_Count': 1520,
#    'FU_Name': '',
#    'IntSCFU': 161,
#    'Mean_CFact': 0.12426562956228,
#    'Mean_Fines': 35.9375,
#    'Mean_KLS': 0.0561828947368425,
#    'Mean_KLSC': 0.000910834755684989,
#    'Mean_KLSC_Fines': 0.000310211907267107,
#    'Mean_LS': 0.129064280736843,
#    'Mean_Scald': 0,
#    'Time_Step': '1/09/1987'},
#   {'Area': 1503630,
#    'Catchment_Name': 'SC #86',
#    'Cell_Count': 50121,
#    'FU_Name': 'Grazing Forested',
#    'IntSCFU': 190,
#    'Mean_CFact': 0.0406193785034281,
#    'Mean_Fines': 53.2326769218491,
#    'Mean_KLS': 0.075229833802252,
#    'Mean_KLSC': 0.0115976097969053,
#    'Mean_KLSC_Fines': 0.00710147129697587,
#    'Mean_LS': 3.50731729144333,
#    'Mean_Scald': 0,
#    'Time_Step': '1/09/1987'},
#   {'Area': 65910,
#    'Catchment_Name': 'SC #36',
#    'Cell_Count': 2197,
#    'FU_Name': 'Grazing Forested',
#    'IntSCFU': 92,
#    'Mean_CFact': 0.0748397862802789,
#    'Mean_Fines': 26.8607191624943,
#    'Mean_KLS': 0.0493680928538921,
#    'Mean_KLSC': 0.000979360735090095,
#    'Mean_KLSC_Fines': 0.000282109437519102,
#    'Mean_LS': 0.530292423586709,
#    'Mean_Scald': 0,
#    'Time_Step': '1/09/1987'},
#   {'Area': 990,
#    'Catchment_Name': 'SC #91',
#    'Cell_Count': 33,
#    'FU_Name': 'Grazing Forested',
#    'IntSCFU': 223,
#    'Mean_CFact': 0.0239651861007918,
#    'Mean_Fines': 28,
#    'Mean_KLS': 0.0372,
#    'Mean_KLSC': 0.00210155176760275,
#    'Mean_KLSC_Fines': 0.000588434494928769,
#    'Mean_LS': 2.31298384242424,
#    'Mean_Scald': 0,
#    'Time_Step': '1/09/1987'},
#   {'Area': 440880,
#    'Catchment_Name': 'SC #4',
#    'Cell_Count': 14696,
#    'FU_Name': 'Conservation',
#    'IntSCFU': 256,
#    'Mean_CFact': 0.0462037776905023,
#    'Mean_Fines': 32.4421611322809,
#    'Mean_KLS': 0.0587145073489469,
#    'Mean_KLSC': 0.0110057844831893,
#    'Mean_KLSC_Fines': 0.00382281683746347,
#    'Mean_LS': 3.77501349112957,
#    'Mean_Scald': 0,
#    'Time_Step': '1/09/1987'},
#   {'Area': 60660,
#    'Catchment_Name': '',
#    'Cell_Count': 2022,
#    'FU_Name': '',
#    'IntSCFU': 43,
#    'Mean_CFact': 0.136010018065176,
#    'Mean_Fines': 46.2527200791296,
#    'Mean_KLS': 0.07594075173096,
#    'Mean_KLSC': 0.000731673636745358,
#    'Mean_KLSC_Fines': 0.000366349315890106,
#    'Mean_LS': 0.0808243811028697,
#    'Mean_Scald': 0,
#    'Time_Step': '1/09/1987'},
#   {'Area': 69630,
#    'Catchment_Name': 'SC #24',
#    'Cell_Count': 2321,
#    'FU_Name': 'Grazing Forested',
#    'IntSCFU': 289,
#    'Mean_CFact': 0.0176037156818782,
#    'Mean_Fines': 50.4049978457561,
#    'Mean_KLS': 0.0688883239982778,
#    'Mean_KLSC': 7.91079787178068e-05,
#    'Mean_KLSC_Fines': 3.94238150549866e-05,
#    'Mean_LS': 0.0694959164411899,
#    'Mean_Scald': 0,
#    'Time_Step': '1/09/1987'},
#   {'Area': 25530,
#    'Catchment_Name': '',
#    'Cell_Count': 851,
#    'FU_Name': '',
#    'IntSCFU': 1105,
#    'Mean_CFact': 0.144991976783538,
#    'Mean_Fines': 36.8237367802585,
#    'Mean_KLS': 0.0518011750881314,
#    'Mean_KLSC': 0.000969726119330197,
#    'Mean_KLSC_Fines': 0.000332655390232163,
#    'Mean_LS': 0.133376225076381,
#    'Mean_Scald': 0,
#    'Time_Step': '1/09/1987'},
#   {'Area': 254970,
#    'Catchment_Name': 'SC #129',
#    'Cell_Count': 8499,
#    'FU_Name': 'Grazing Open',
#    'IntSCFU': 1171,
#    'Mean_CFact': 0.0481507113353641,
#    'Mean_Fines': 31.2050829509354,
#    'Mean_KLS': 0.052169490528299,
#    'Mean_KLSC': 0.000273882500395858,
#    'Mean_KLSC_Fines': 8.24225414777547e-05,
#    'Mean_LS': 0.158320854452287,
#    'Mean_Scald': 0,
#    'Time_Step': '1/09/1987'},
#   {'Area': 7710,
#    'Catchment_Name': '',
#    'Cell_Count': 257,
#    'FU_Name': '',
#    'IntSCFU': 1237,
#    'Mean_CFact': 0.128675508664392,
#    'Mean_Fines': 26.9727626459144,
#    'Mean_KLS': 0.0420836575875485,
#    'Mean_KLSC': 0.000306320137232703,
#    'Mean_KLSC_Fines': 8.0864148883715e-05,
#    'Mean_LS': 0.05699991,
#    'Mean_Scald': 0,
#    'Time_Step': '1/09/1987'},
#   {'Area': 33690,
#    'Catchment_Name': 'SC #151',
#    'Cell_Count': 1123,
#    'FU_Name': 'Grazing Open',
#    'IntSCFU': 355,
#    'Mean_CFact': 0.0362577759125871,
#    'Mean_Fines': 28.5618878005343,
#    'Mean_KLS': 0.0452312555654498,
#    'Mean_KLSC': 0.00116646526332923,
#    'Mean_KLSC_Fines': 0.000327067623694238,
#    'Mean_LS': 0.973592523410508,
#    'Mean_Scald': 0,
#    'Time_Step': '1/09/1987'},
#   {'Area': 322830,
#    'Catchment_Name': 'SC #54',
#    'Cell_Count': 10761,
#    'FU_Name': 'Grazing Open',
#    'IntSCFU': 20,
#    'Mean_CFact': 0.0246423362416236,
#    'Mean_Fines': 32.9547439829012,
#    'Mean_KLS': 0.0484644085122248,
#    'Mean_KLSC': 0.000913214518226841,
#    'Mean_KLSC_Fines': 0.000231100335684526,
#    'Mean_LS': 0.610507176534674,
#    'Mean_Scald': 0,
#    'Time_Step': '1/09/1987'},
#   {'Area': 870,
#    'Catchment_Name': '',
#    'Cell_Count': 29,
#    'FU_Name': '',
#    'IntSCFU': 388,
#    'Mean_CFact': 0.10547910251751,
#    'Mean_Fines': 31.6551724137931,
#    'Mean_KLS': 0.0536586206896551,
#    'Mean_KLSC': 0.00196789544502017,
#    'Mean_KLSC_Fines': 0.000628936985305874,
#    'Mean_LS': 0.341132072068966,
#    'Mean_Scald': 0,
#    'Time_Step': '1/09/1987'},
#   {'Area': 13020,
#    'Catchment_Name': 'SC #135',
#    'Cell_Count': 434,
#    'FU_Name': 'Conservation',
#    'IntSCFU': 1211,
#    'Mean_CFact': 0.0732948074786825,
#    'Mean_Fines': 35.5437788018433,
#    'Mean_KLS': 0.0494285714285717,
#    'Mean_KLSC': 0.000245374673286428,
#    'Mean_KLSC_Fines': 0.000100768638106819,
#    'Mean_LS': 0.0618457273041471,
#    'Mean_Scald': 0,
#    'Time_Step': '1/09/1987'},
#   {'Area': 1560,
#    'Catchment_Name': '',
#    'Cell_Count': 52,
#    'FU_Name': '',
#    'IntSCFU': 421,
#    'Mean_CFact': 0.0827488963169834,
#    'Mean_Fines': 37.9615384615385,
#    'Mean_KLS': 0.0624057692307692,
#    'Mean_KLSC': 0.000290216754655717,
#    'Mean_KLSC_Fines': 0.000108930400515716,
#    'Mean_LS': 0.05699991,
#    'Mean_Scald': 0,
#    'Time_Step': '1/09/1987'},
#   {'Area': 444930,
#    'Catchment_Name': 'SC #6',
#    'Cell_Count': 14831,
#    'FU_Name': 'Forestry',
#    'IntSCFU': 31,
#    'Mean_CFact': 0.0441809282995991,
#    'Mean_Fines': 54.232755714382,
#    'Mean_KLS': 0.056646187040677,
#    'Mean_KLSC': 0.0115273878633319,
#    'Mean_KLSC_Fines': 0.00646163052071825,
#    'Mean_LS': 4.75401514780528,
#    'Mean_Scald': 0,
#    'Time_Step': '1/09/1987'},
#   {'Area': 409320,
#    'Catchment_Name': 'SC #44',
#    'Cell_Count': 13644,
#    'FU_Name': 'Grazing Open',
#    'IntSCFU': 329,
#    'Mean_CFact': 0.0180608087781204,
#    'Mean_Fines': 38.2113016710642,
#    'Mean_KLS': 0.0555501099384395,
#    'Mean_KLSC': 0.000253922841558506,
#    'Mean_KLSC_Fines': 9.51736497076778e-05,
#    'Mean_LS': 0.2540900353452,
#    'Mean_Scald': 0,
#    'Time_Step': '1/09/1987'},
#   {'Area': 7860,
#    'Catchment_Name': 'SC #154',
#    'Cell_Count': 262,
#    'FU_Name': 'Grazing Open',
#    'IntSCFU': 843,
#    'Mean_CFact': 0.0276465214547196,
#    'Mean_Fines': 33.5763358778626,
#    'Mean_KLS': 0.0576045801526716,
#    'Mean_KLSC': 0.00015254288193613,
#    'Mean_KLSC_Fines': 5.71322342137685e-05,
#    'Mean_LS': 0.146308899770992,
#    'Mean_Scald': 0,
#    'Time_Step': '1/09/1987'},
#   {'Area': 60150,
#    'Catchment_Name': 'SC #61',
#    'Cell_Count': 2005,
#    'FU_Name': 'Conservation',
#    'IntSCFU': 487,
#    'Mean_CFact': 0.0209900312037428,
#    'Mean_Fines': 44.9825436408978,
#    'Mean_KLS': 0.0610624438902723,
#    'Mean_KLSC': 0.00265645375911243,
#    'Mean_KLSC_Fines': 0.00121725015295472,
#    'Mean_LS': 2.77970228151619,
#    'Mean_Scald': 0,
#    'Time_Step': '1/09/1987'},
#   {'Area': 3870,
#    'Catchment_Name': '',
#    'Cell_Count': 129,
#    'FU_Name': '',
#    'IntSCFU': 528,
#    'Mean_CFact': 0.041126458407488,
#    'Mean_Fines': 30.1085271317829,
#    'Mean_KLS': 0.0461387596899225,
#    'Mean_KLSC': 0.00300079534726418,
#    'Mean_KLSC_Fines': 0.000872823457317122,
#    'Mean_LS': 1.67828595604651,
#    'Mean_Scald': 0,
#    'Time_Step': '1/09/1987'},
#   {'Area': 1260,
#    'Catchment_Name': '',
#    'Cell_Count': 42,
#    'FU_Name': '',
#    'IntSCFU': 561,
#    'Mean_CFact': 0.0724806386556122,
#    'Mean_Fines': 37.2380952380952,
#    'Mean_KLS': 0.0635619047619048,
#    'Mean_KLSC': 0.000532133094446987,
#    'Mean_KLSC_Fines': 0.000193195567387807,
#    'Mean_LS': 0.102482791428571,
#    'Mean_Scald': 0,
#    'Time_Step': '1/09/1987'},
#   {'Area': 160830,
#    'Catchment_Name': 'SC #90184',
#    'Cell_Count': 5361,
#    'FU_Name': 'Grazing Open',
#    'IntSCFU': 1017,
#    'Mean_CFact': 0.0838275857103338,
#    'Mean_Fines': 48.4984144749114,
#    'Mean_KLS': 0.0618156500652913,
#    'Mean_KLSC': 0.00126808261433328,
#    'Mean_KLSC_Fines': 0.000620760388093098,
#    'Mean_LS': 0.356527155588508,
#    'Mean_Scald': 0,
#    'Time_Step': '1/09/1987'},
#   {'Area': 410130,
#    'Catchment_Name': '',
#    'Cell_Count': 13671,
#    'FU_Name': '',
#    'IntSCFU': 51,
#    'Mean_CFact': 0.0903205023195943,
#    'Mean_Fines': 13.9718381976446,
#    'Mean_KLS': 0.0362376344086077,
#    'Mean_KLSC': 0.000195021778185294,
#    'Mean_KLSC_Fines': 2.99521056729038e-05,
#    'Mean_LS': 0.0658694810664682,
#    'Mean_Scald': 0,
#    'Time_Step': '1/09/1987'},
#   {'Area': 25020,
#    'Catchment_Name': '',
#    'Cell_Count': 834,
#    'FU_Name': '',
#    'IntSCFU': 1247,
#    'Mean_CFact': 0.084939348778846,
#    'Mean_Fines': 47.2290167865707,
#    'Mean_KLS': 0.0552673860911278,
#    'Mean_KLSC': 0.000328220975711077,
#    'Mean_KLSC_Fines': 0.000170288410390864,
#    'Mean_LS': 0.100348386762591,
#    'Mean_Scald': 0,
#    'Time_Step': '1/09/1987'},
#   {'Area': 789270,
#    'Catchment_Name': '',
#    'Cell_Count': 26309,
#    'FU_Name': '',
#    'IntSCFU': 693,
#    'Mean_CFact': 0.0568433778724463,
#    'Mean_Fines': 48.6214223269604,
#    'Mean_KLS': 0.0689847542666177,
#    'Mean_KLSC': 0.000263263635627845,
#    'Mean_KLSC_Fines': 0.000134152338140277,
#    'Mean_LS': 0.0745368152012622,
#    'Mean_Scald': 0,
#    'Time_Step': '1/09/1987'},
#   {'Area': 1260,
#    'Catchment_Name': '',
#    'Cell_Count': 42,
#    'FU_Name': '',
#    'IntSCFU': 726,
#    'Mean_CFact': 0.0311160744278736,
#    'Mean_Fines': 66.3333333333333,
#    'Mean_KLS': 0.0622666666666667,
#    'Mean_KLSC': 0.00163290817284889,
#    'Mean_KLSC_Fines': 0.00106235993428969,
#    'Mean_LS': 0.781528886666667,
#    'Mean_Scald': 0,
#    'Time_Step': '1/09/1987'},
#   {'Area': 450,
#    'Catchment_Name': '',
#    'Cell_Count': 15,
#    'FU_Name': '',
#    'IntSCFU': 759,
#    'Mean_CFact': 0.0524900512148937,
#    'Mean_Fines': 72,
#    'Mean_KLS': 0.0885,
#    'Mean_KLSC': 0.000264785645270273,
#    'Mean_KLSC_Fines': 0.000190645664594597,
#    'Mean_LS': 0.05699991,
#    'Mean_Scald': 0,
#    'Time_Step': '1/09/1987'},
#   {'Area': 59370,
#    'Catchment_Name': 'SC #162',
#    'Cell_Count': 1979,
#    'FU_Name': 'Grazing Forested',
#    'IntSCFU': 792,
#    'Mean_CFact': 0.0124936946808912,
#    'Mean_Fines': 55.1566447700859,
#    'Mean_KLS': 0.061936584133402,
#    'Mean_KLSC': 0.0010137581285864,
#    'Mean_KLSC_Fines': 0.000642965889290114,
#    'Mean_LS': 1.53048948848909,
#    'Mean_Scald': 0,
#    'Time_Step': '1/09/1987'},
#   {'Area': 22200,
#    'Catchment_Name': '',
#    'Cell_Count': 740,
#    'FU_Name': '',
#    'IntSCFU': 825,
#    'Mean_CFact': 0.119555272292849,
#    'Mean_Fines': 46.1364864864865,
#    'Mean_KLS': 0.0769328378378385,
#    'Mean_KLSC': 0.00168722864367365,
#    'Mean_KLSC_Fines': 0.000641523199596818,
#    'Mean_LS': 0.144912284013515,
#    'Mean_Scald': 0,
#    'Time_Step': '1/09/1987'},
#   {'Area': 43380,
#    'Catchment_Name': '',
#    'Cell_Count': 1446,
#    'FU_Name': '',
#    'IntSCFU': 858,
#    'Mean_CFact': 0.055539721462046,
#    'Mean_Fines': 41.8845089903181,
#    'Mean_KLS': 0.0607199861687408,
#    'Mean_KLSC': 0.00144823005626738,
#    'Mean_KLSC_Fines': 0.00061177951053339,
#    'Mean_LS': 0.650173308540794,
#    'Mean_Scald': 0,
#    'Time_Step': '1/09/1987'},
#   {'Area': 4440,
#    'Catchment_Name': '',
#    'Cell_Count': 148,
#    'FU_Name': '',
#    'IntSCFU': 891,
#    'Mean_CFact': 0.105614810514994,
#    'Mean_Fines': 39.8040540540541,
#    'Mean_KLS': 0.0742209459459458,
#    'Mean_KLSC': 0.00222294891805876,
#    'Mean_KLSC_Fines': 0.000942335370946616,
#    'Mean_LS': 0.488278342635136,
#    'Mean_Scald': 0,
#    'Time_Step': '1/09/1987'},
#   {'Area': 840,
#    'Catchment_Name': '',
#    'Cell_Count': 28,
#    'FU_Name': '',
#    'IntSCFU': 1185,
#    'Mean_CFact': 0.026715656642669,
#    'Mean_Fines': 42.9285714285714,
#    'Mean_KLS': 0.0542892857142857,
#    'Mean_KLSC': 0.000460357032288426,
#    'Mean_KLSC_Fines': 0.000180328304768723,
#    'Mean_LS': 0.472117319642857,
#    'Mean_Scald': 0,
#    'Time_Step': '1/09/1987'},
#   {'Area': 354150,
#    'Catchment_Name': 'SC #160',
#    'Cell_Count': 11805,
#    'FU_Name': 'Conservation',
#    'IntSCFU': 957,
#    'Mean_CFact': 0.0430085701221506,
#    'Mean_Fines': 21.944430326133,
#    'Mean_KLS': 0.0318135281660364,
#    'Mean_KLSC': 0.00626646001893516,
#    'Mean_KLSC_Fines': 0.00135285918436165,
#    'Mean_LS': 4.86152853982467,
#    'Mean_Scald': 0,
#    'Time_Step': '1/09/1987'},
#   {'Area': 17310,
#    'Catchment_Name': '',
#    'Cell_Count': 577,
#    'FU_Name': '',
#    'IntSCFU': 990,
#    'Mean_CFact': 0.107874963910317,
#    'Mean_Fines': 37.5025996533795,
#    'Mean_KLS': 0.066309358752166,
#    'Mean_KLSC': 0.000427821299351642,
#    'Mean_KLSC_Fines': 0.000185995035326495,
#    'Mean_LS': 0.0571446999133441,
#    'Mean_Scald': 0,
#    'Time_Step': '1/09/1987'},
#   {'Area': 266400,
#    'Catchment_Name': 'SC #126',
#    'Cell_Count': 8880,
#    'FU_Name': 'Forestry',
#    'IntSCFU': 1023,
#    'Mean_CFact': 0.0419497303047425,
#    'Mean_Fines': 23.3243243243243,
#    'Mean_KLS': 0.0319802252252258,
#    'Mean_KLSC': 0.00615483616370109,
#    'Mean_KLSC_Fines': 0.00142544756388621,
#    'Mean_LS': 4.64757298630291,
#    'Mean_Scald': 0,
#    'Time_Step': '1/09/1987'},
#   {'Area': 94380,
#    'Catchment_Name': 'SC #159',
#    'Cell_Count': 3146,
#    'FU_Name': 'Grazing Open',
#    'IntSCFU': 1088,
#    'Mean_CFact': 0.0608456908710104,
#    'Mean_Fines': 29.0301970756516,
#    'Mean_KLS': 0.041200190718372,
#    'Mean_KLSC': 0.000521885903617135,
#    'Mean_KLSC_Fines': 0.000150883726383701,
#    'Mean_LS': 0.32160845191035,
#    'Mean_Scald': 0,
#    'Time_Step': '1/09/1987'},
#   {'Area': 113730,
#    'Catchment_Name': '',
#    'Cell_Count': 3791,
#    'FU_Name': '',
#    'IntSCFU': 1154,
#    'Mean_CFact': 0.10827338745679,
#    'Mean_Fines': 56.6228425428647,
#    'Mean_KLS': 0.0714386019519895,
#    'Mean_KLSC': 0.000458681911866813,
#    'Mean_KLSC_Fines': 0.000268627699879671,
#    'Mean_LS': 0.0585850921709325,
#    'Mean_Scald': 0,
#    'Time_Step': '1/09/1987'},
#   {'Area': 65670,
#    'Catchment_Name': '',
#    'Cell_Count': 2189,
#    'FU_Name': '',
#    'IntSCFU': 1220,
#    'Mean_CFact': 0.244470063377429,
#    'Mean_Fines': 23.0360895386021,
#    'Mean_KLS': 0.046837048880768,
#    'Mean_KLSC': 0.000821314247490276,
#    'Mean_KLSC_Fines': 0.00019395914262,
#    'Mean_LS': 0.0801247696847885,
#    'Mean_Scald': 0,
#    'Time_Step': '1/09/1987'},
#   {'Area': 6480,
#    'Catchment_Name': '',
#    'Cell_Count': 216,
#    'FU_Name': '',
#    'IntSCFU': 95,
#    'Mean_CFact': 0.0408190564097216,
#    'Mean_Fines': 44.2685185185185,
#    'Mean_KLS': 0.0650430555555554,
#    'Mean_KLSC': 0.00030976814169677,
#    'Mean_KLSC_Fines': 0.000115356312180815,
#    'Mean_LS': 0.142447862638889,
#    'Mean_Scald': 0,
#    'Time_Step': '1/09/1987'},
#   {'Area': 73140,
#    'Catchment_Name': 'SC #121',
#    'Cell_Count': 2438,
#    'FU_Name': 'Grazing Forested',
#    'IntSCFU': 1143,
#    'Mean_CFact': 0.0403986570391115,
#    'Mean_Fines': 55.2510254306809,
#    'Mean_KLS': 0.056050082034455,
#    'Mean_KLSC': 0.00434861773915134,
#    'Mean_KLSC_Fines': 0.00250995064968384,
#    'Mean_LS': 1.84292855305985,
#    'Mean_Scald': 0,
#    'Time_Step': '1/09/1987'},
#   {'Area': 1019070,
#    'Catchment_Name': '',
#    'Cell_Count': 33969,
#    'FU_Name': '',
#    'IntSCFU': 312,
#    'Mean_CFact': 0.0904723977820153,
#    'Mean_Fines': 40.9321734522653,
#    'Mean_KLS': 0.0570267390856457,
#    'Mean_KLSC': 0.000558534848194528,
#    'Mean_KLSC_Fines': 0.000239480517144305,
#    'Mean_LS': 0.160790014002344,
#    'Mean_Scald': 0,
#    'Time_Step': '1/09/1987'},
#   {'Area': 15390,
#    'Catchment_Name': 'SC #147',
#    'Cell_Count': 513,
#    'FU_Name': 'Conservation',
#    'IntSCFU': 128,
#    'Mean_CFact': 0.0352291626470857,
#    'Mean_Fines': 44.3840155945419,
#    'Mean_KLS': 0.0604988304093564,
#    'Mean_KLSC': 0.00803051852377151,
#    'Mean_KLSC_Fines': 0.00392635763675916,
#    'Mean_LS': 3.39090745054582,
#    'Mean_Scald': 0,
#    'Time_Step': '1/09/1987'},
#   {'Area': 591690,
#    'Catchment_Name': 'SC #137',
#    'Cell_Count': 19723,
#    'FU_Name': 'Forestry',
#    'IntSCFU': 1126,
#    'Mean_CFact': 0.0414612858101001,
#    'Mean_Fines': 28.3979617705217,
#    'Mean_KLS': 0.0363292906758607,
#    'Mean_KLSC': 0.004467110449945,
#    'Mean_KLSC_Fines': 0.00127521976223852,
#    'Mean_LS': 2.98084451470669,
#    'Mean_Scald': 0,
#    'Time_Step': '1/09/1987'},
#   {'Area': 1590,
#    'Catchment_Name': 'SC #120',
#    'Cell_Count': 53,
#    'FU_Name': 'Forestry',
#    'IntSCFU': 924,
#    'Mean_CFact': 0.125457265994178,
#    'Mean_Fines': 78,
#    'Mean_KLS': 0.0955,
#    'Mean_KLSC': 0.000682925549134105,
#    'Mean_KLSC_Fines': 0.000532681928324602,
#    'Mean_LS': 0.05699991,
#    'Mean_Scald': 0,
#    'Time_Step': '1/09/1987'},
#   {'Area': 113220,
#    'Catchment_Name': 'SC #114',
#    'Cell_Count': 3774,
#    'FU_Name': 'Forestry',
#    'IntSCFU': 795,
#    'Mean_CFact': 0.0429226466377819,
#    'Mean_Fines': 27.9788023317435,
#    'Mean_KLS': 0.042932962374141,
#    'Mean_KLSC': 0.00940890792672858,
#    'Mean_KLSC_Fines': 0.00263400268330953,
#    'Mean_LS': 4.91030739165076,
#    'Mean_Scald': 0,
#    'Time_Step': '1/09/1987'},
#   {'Area': 387180,
#    'Catchment_Name': 'SC #48',
#    'Cell_Count': 12906,
#    'FU_Name': 'Forestry',
#    'IntSCFU': 194,
#    'Mean_CFact': 0.0358685653567385,
#    'Mean_Fines': 31.547419804742,
#    'Mean_KLS': 0.0478479079497875,
#    'Mean_KLSC': 0.00632276492396915,
#    'Mean_KLSC_Fines': 0.00205588137025041,
#    'Mean_LS': 3.49548603011704,
#    'Mean_Scald': 0,
#    'Time_Step': '1/09/1987'},
#   {'Area': 187890,
#    'Catchment_Name': 'SC #35',
#    'Cell_Count': 6263,
#    'FU_Name': 'Conservation',
#    'IntSCFU': 66,
#    'Mean_CFact': 0.0485445588375673,
#    'Mean_Fines': 33.6468146255788,
#    'Mean_KLS': 0.0505251796263763,
#    'Mean_KLSC': 0.00905470279798254,
#    'Mean_KLSC_Fines': 0.00287680520688448,
#    'Mean_LS': 3.73225481992017,
#    'Mean_Scald': 0,
#    'Time_Step': '1/09/1987'},
#   {'Area': 1152780,
#    'Catchment_Name': '',
#    'Cell_Count': 38426,
#    'FU_Name': '',
#    'IntSCFU': 227,
#    'Mean_CFact': 0.0961065652208683,
#    'Mean_Fines': 50.1998906990059,
#    'Mean_KLS': 0.0638353796908495,
#    'Mean_KLSC': 0.000620959908294953,
#    'Mean_KLSC_Fines': 0.000305542817523334,
#    'Mean_LS': 0.119230379754803,
#    'Mean_Scald': 0,
#    'Time_Step': '1/09/1987'},
#   {'Area': 142470,
#    'Catchment_Name': '',
#    'Cell_Count': 4749,
#    'FU_Name': '',
#    'IntSCFU': 264,
#    'Mean_CFact': 0.0634569827511132,
#    'Mean_Fines': 43.8387028848179,
#    'Mean_KLS': 0.0536177511054965,
#    'Mean_KLSC': 0.000276252633272388,
#    'Mean_KLSC_Fines': 0.000114762634356578,
#    'Mean_LS': 0.0913614628258598,
#    'Mean_Scald': 0,
#    'Time_Step': '1/09/1987'},
#   {'Area': 690,
#    'Catchment_Name': '',
#    'Cell_Count': 23,
#    'FU_Name': '',
#    'IntSCFU': 1071,
#    'Mean_CFact': 0.158207670340072,
#    'Mean_Fines': 25,
#    'Mean_KLS': 0.0608,
#    'Mean_KLSC': 0.00054828363661818,
#    'Mean_KLSC_Fines': 0.000137070909154545,
#    'Mean_LS': 0.05699991,
#    'Mean_Scald': 0,
#    'Time_Step': '1/09/1987'},
#   {'Area': 810,
#    'Catchment_Name': '',
#    'Cell_Count': 27,
#    'FU_Name': '',
#    'IntSCFU': 1137,
#    'Mean_CFact': 0.039135436112958,
#    'Mean_Fines': 37,
#    'Mean_KLS': 0.0528,
#    'Mean_KLSC': 0.000117781822553966,
#    'Mean_KLSC_Fines': 4.35792743449674e-05,
#    'Mean_LS': 0.05699991,
#    'Mean_Scald': 0,
#    'Time_Step': '1/09/1987'},
#   {'Area': 3750,
#    'Catchment_Name': '',
#    'Cell_Count': 125,
#    'FU_Name': '',
#    'IntSCFU': 1203,
#    'Mean_CFact': 0.0698897479176521,
#    'Mean_Fines': 29.272,
#    'Mean_KLS': 0.0441920000000001,
#    'Mean_KLSC': 0.000752541582502493,
#    'Mean_KLSC_Fines': 0.000215220699988045,
#    'Mean_LS': 0.264940874959999,
#    'Mean_Scald': 0,
#    'Time_Step': '1/09/1987'},
#   {'Area': 4260,
#    'Catchment_Name': 'SC #139',
#    'Cell_Count': 142,
#    'FU_Name': 'Grazing Open',
#    'IntSCFU': 1269,
#    'Mean_CFact': 0.0414373735418726,
#    'Mean_Fines': 46.2816901408451,
#    'Mean_KLS': 0.0681908450704226,
#    'Mean_KLSC': 0.000160570808937878,
#    'Mean_KLSC_Fines': 8.32885121442048e-05,
#    'Mean_LS': 0.05699991,
#    'Mean_Scald': 0,
#    'Time_Step': '1/09/1987'},
#   {'Area': 3900,
#    'Catchment_Name': '',
#    'Cell_Count': 130,
#    'FU_Name': '',
#    'IntSCFU': 1075,
#    'Mean_CFact': 0.0499470316088544,
#    'Mean_Fines': 24.7153846153846,
#    'Mean_KLS': 0.0312215384615384,
#    'Mean_KLSC': 9.28362536539205e-05,
#    'Mean_KLSC_Fines': 2.65467966963198e-05,
#    'Mean_LS': 0.05699991,
#    'Mean_Scald': 0,
#    'Time_Step': '1/09/1987'},
#   {'Area': 977520,
#    'Catchment_Name': 'SC #55',
#    'Cell_Count': 32584,
#    'FU_Name': 'Grazing Forested',
#    'IntSCFU': 396,
#    'Mean_CFact': 0.0317990675049471,
#    'Mean_Fines': 41.6810090842131,
#    'Mean_KLS': 0.0589765805303152,
#    'Mean_KLSC': 0.0030463545973861,
#    'Mean_KLSC_Fines': 0.00135065352178315,
#    'Mean_LS': 1.5429324510008,
#    'Mean_Scald': 0,
#    'Time_Step': '1/09/1987'},
#   {'Area': 174900,
#    'Catchment_Name': '',
#    'Cell_Count': 5830,
#    'FU_Name': '',
#    'IntSCFU': 429,
#    'Mean_CFact': 0.0256342619703044,
#    'Mean_Fines': 32.608576329331,
#    'Mean_KLS': 0.0511589879931399,
#    'Mean_KLSC': 0.00036079049347172,
#    'Mean_KLSC_Fines': 0.000120660757385079,
#    'Mean_LS': 0.252569723461405,
#    'Mean_Scald': 0,
#    'Time_Step': '1/09/1987'},
#   {'Area': 4650,
#    'Catchment_Name': '',
#    'Cell_Count': 155,
#    'FU_Name': '',
#    'IntSCFU': 462,
#    'Mean_CFact': 0.042541682152378,
#    'Mean_Fines': 38.5806451612903,
#    'Mean_KLS': 0.0686012903225807,
#    'Mean_KLSC': 0.000967079181725151,
#    'Mean_KLSC_Fines': 0.000357311512914178,
#    'Mean_LS': 0.37576232883871,
#    'Mean_Scald': 0,
#    'Time_Step': '1/09/1987'},
#   {'Area': 33510,
#    'Catchment_Name': 'SC #18',
#    'Cell_Count': 1117,
#    'FU_Name': 'Grazing Open',
#    'IntSCFU': 495,
#    'Mean_CFact': 0.0138897061578916,
#    'Mean_Fines': 54.1271262309758,
#    'Mean_KLS': 0.0529132497761853,
#    'Mean_KLSC': 4.12939976663125e-05,
#    'Mean_KLSC_Fines': 2.23132129582878e-05,
#    'Mean_LS': 0.0569999100000005,
#    'Mean_Scald': 0,
#    'Time_Step': '1/09/1987'},
#   {'Area': 60330,
#    'Catchment_Name': '',
#    'Cell_Count': 2011,
#    'FU_Name': '',
#    'IntSCFU': 544,
#    'Mean_CFact': 0.0497848829317028,
#    'Mean_Fines': 39.921929388364,
#    'Mean_KLS': 0.0563790651417182,
#    'Mean_KLSC': 0.000825132586732927,
#    'Mean_KLSC_Fines': 0.000352217179662839,
#    'Mean_LS': 0.385451569547489,
#    'Mean_Scald': 0,
#    'Time_Step': '1/09/1987'},
#   {'Area': 883110,
#    'Catchment_Name': 'SC #90172',
#    'Cell_Count': 29437,
#    'FU_Name': 'Conservation',
#    'IntSCFU': 577,
#    'Mean_CFact': 0.0417925045423036,
#    'Mean_Fines': 45.3200575017835,
#    'Mean_KLS': 0.0592804885008616,
#    'Mean_KLSC': 0.0107349887818805,
#    'Mean_KLSC_Fines': 0.00486525403733957,
#    'Mean_LS': 4.50796284931277,
#    'Mean_Scald': 0,
#    'Time_Step': '1/09/1987'},
#   {'Area': 17520,
#    'Catchment_Name': '',
#    'Cell_Count': 584,
#    'FU_Name': '',
#    'IntSCFU': 610,
#    'Mean_CFact': 0.0294125631574401,
#    'Mean_Fines': 43.9383561643836,
#    'Mean_KLS': 0.0545303082191782,
#    'Mean_KLSC': 0.0027431067258666,
#    'Mean_KLSC_Fines': 0.00121391124461071,
#    'Mean_LS': 1.67782090308219,
#    'Mean_Scald': 0,
#    'Time_Step': '1/09/1987'},
#   {'Area': 2340,
#    'Catchment_Name': '',
#    'Cell_Count': 78,
#    'FU_Name': '',
#    'IntSCFU': 643,
#    'Mean_CFact': 0.0419999999999999,
#    'Mean_Fines': 43,
#    'Mean_KLS': 0.0648692307692308,
#    'Mean_KLSC': 0.000155296693255846,
#    'Mean_KLSC_Fines': 6.67610042800294e-05,
#    'Mean_LS': 0.05699991,
#    'Mean_Scald': 0,
#    'Time_Step': '1/09/1987'},
#   {'Area': 330,
#    'Catchment_Name': 'SC #40',
#    'Cell_Count': 11,
#    'FU_Name': 'Grazing Forested',
#    'IntSCFU': 676,
#    'Mean_CFact': 0.042,
#    'Mean_Fines': 45,
#    'Mean_KLS': 0.0589,
#    'Mean_KLSC': 0.0095938466316,
#    'Mean_KLSC_Fines': 0.00431723098422,
#    'Mean_LS': 3.878182,
#    'Mean_Scald': 0,
#    'Time_Step': '1/09/1987'},
#   {'Area': 1470,
#    'Catchment_Name': '',
#    'Cell_Count': 49,
#    'FU_Name': '',
#    'IntSCFU': 709,
#    'Mean_CFact': 0.042,
#    'Mean_Fines': 47.6938775510204,
#    'Mean_KLS': 0.0709979591836735,
#    'Mean_KLSC': 0.000169968845913429,
#    'Mean_KLSC_Fines': 8.09452139058514e-05,
#    'Mean_LS': 0.05699991,
#    'Mean_Scald': 0,
#    'Time_Step': '1/09/1987'},
#   {'Area': 234480,
#    'Catchment_Name': 'SC #70',
#    'Cell_Count': 7816,
#    'FU_Name': 'Forestry',
#    'IntSCFU': 742,
#    'Mean_CFact': 0.0351799241722488,
#    'Mean_Fines': 64.8986693961105,
#    'Mean_KLS': 0.062575793244616,
#    'Mean_KLSC': 0.00587342991896738,
#    'Mean_KLSC_Fines': 0.00381550981598454,
#    'Mean_LS': 2.72300161909033,
#    'Mean_Scald': 0,
#    'Time_Step': '1/09/1987'},
#   {'Area': 310680,
#    'Catchment_Name': '',
#    'Cell_Count': 10356,
#    'FU_Name': '',
#    'IntSCFU': 775,
#    'Mean_CFact': 0.137408219216481,
#    'Mean_Fines': 71.0719389725763,
#    'Mean_KLS': 0.0908792197759765,
#    'Mean_KLSC': 0.000728440718797075,
#    'Mean_KLSC_Fines': 0.000535838081747608,
#    'Mean_LS': 0.0588694894621411,
#    'Mean_Scald': 0,
#    'Time_Step': '1/09/1987'},
#   {'Area': 35070,
#    'Catchment_Name': 'SC #114',
#    'Cell_Count': 1169,
#    'FU_Name': 'Grazing Open',
#    'IntSCFU': 808,
#    'Mean_CFact': 0.047965359874468,
#    'Mean_Fines': 26.901625320787,
#    'Mean_KLS': 0.0459188195038502,
#    'Mean_KLSC': 0.00217421401192553,
#    'Mean_KLSC_Fines': 0.000591853583295195,
#    'Mean_LS': 0.79087642152264,
#    'Mean_Scald': 0,
#    'Time_Step': '1/09/1987'},
#   {'Area': 17310,
#    'Catchment_Name': '',
#    'Cell_Count': 577,
#    'FU_Name': '',
#    'IntSCFU': 841,
#    'Mean_CFact': 0.0937131312546648,
#    'Mean_Fines': 35.0277296360485,
#    'Mean_KLS': 0.0662585788561522,
#    'Mean_KLSC': 0.000753461466656127,
#    'Mean_KLSC_Fines': 0.000304359202224461,
#    'Mean_LS': 0.107467796897748,
#    'Mean_Scald': 0,
#    'Time_Step': '1/09/1987'},
#   {'Area': 17460,
#    'Catchment_Name': '',
#    'Cell_Count': 582,
#    'FU_Name': '',
#    'IntSCFU': 874,
#    'Mean_CFact': 0.0619418390312863,
#    'Mean_Fines': 47.819587628866,
#    'Mean_KLS': 0.0742008591065291,
#    'Mean_KLSC': 0.000431388226817114,
#    'Mean_KLSC_Fines': 0.000220998313438185,
#    'Mean_LS': 0.103359115206187,
#    'Mean_Scald': 0,
#    'Time_Step': '1/09/1987'},
#   {'Area': 32490,
#    'Catchment_Name': '',
#    'Cell_Count': 1083,
#    'FU_Name': '',
#    'IntSCFU': 907,
#    'Mean_CFact': 0.0391729091795459,
#    'Mean_Fines': 33.1468144044321,
#    'Mean_KLS': 0.0514782086795928,
#    'Mean_KLSC': 0.000556221439376514,
#    'Mean_KLSC_Fines': 0.000181968551372132,
#    'Mean_LS': 0.498171926666667,
#    'Mean_Scald': 0,
#    'Time_Step': '1/09/1987'},
#   {'Area': 2130,
#    'Catchment_Name': '',
#    'Cell_Count': 71,
#    'FU_Name': '',
#    'IntSCFU': 940,
#    'Mean_CFact': 0.0583123195863945,
#    'Mean_Fines': 31,
#    'Mean_KLS': 0.0586000000000001,
#    'Mean_KLSC': 0.000194774502343302,
#    'Mean_KLSC_Fines': 6.03800957264235e-05,
#    'Mean_LS': 0.05699991,
#    'Mean_Scald': 0,
#    'Time_Step': '1/09/1987'},
#   {'Area': 550770,
#    'Catchment_Name': '',
#    'Cell_Count': 18359,
#    'FU_Name': '',
#    'IntSCFU': 973,
#    'Mean_CFact': 0.133889054443409,
#    'Mean_Fines': 51.361893349311,
#    'Mean_KLS': 0.0794535541151293,
#    'Mean_KLSC': 0.000610781378760993,
#    'Mean_KLSC_Fines': 0.000322750105051265,
#    'Mean_LS': 0.0574254825785485,
#    'Mean_Scald': 0,
#    'Time_Step': '1/09/1987'},
#   {'Area': 36150,
#    'Catchment_Name': 'SC #73',
#    'Cell_Count': 1205,
#    'FU_Name': 'Grazing Forested',
#    'IntSCFU': 1006,
#    'Mean_CFact': 0.0243389580557239,
#    'Mean_Fines': 41.2340248962656,
#    'Mean_KLS': 0.0658220746887953,
#    'Mean_KLSC': 0.000904431534297367,
#    'Mean_KLSC_Fines': 0.000392397137215898,
#    'Mean_LS': 0.546830465933588,
#    'Mean_Scald': 0,
#    'Time_Step': '1/09/1987'},
#   {'Area': 485490,
#    'Catchment_Name': '',
#    'Cell_Count': 16183,
#    'FU_Name': '',
#    'IntSCFU': 1054,
#    'Mean_CFact': 0.0951367572290594,
#    'Mean_Fines': 43.1558425508249,
#    'Mean_KLS': 0.055611654205027,
#    'Mean_KLSC': 0.000754428489692151,
#    'Mean_KLSC_Fines': 0.000308264960961705,
#    'Mean_LS': 0.168715103844757,
#    'Mean_Scald': 0,
#    'Time_Step': '1/09/1987'},
#   {'Area': 3240,
#    'Catchment_Name': '',
#    'Cell_Count': 108,
#    'FU_Name': '',
#    'IntSCFU': 1120,
#    'Mean_CFact': 0.125949008338567,
#    'Mean_Fines': 34.7037037037037,
#    'Mean_KLS': 0.0529574074074074,
#    'Mean_KLSC': 0.00191910887899313,
#    'Mean_KLSC_Fines': 0.000665997462188417,
#    'Mean_LS': 0.398003795277778,
#    'Mean_Scald': 0,
#    'Time_Step': '1/09/1987'},
#   {'Area': 1321260,
#    'Catchment_Name': 'SC #90191',
#    'Cell_Count': 44042,
#    'FU_Name': 'Grazing Forested',
#    'IntSCFU': 1186,
#    'Mean_CFact': 0.028098434944539,
#    'Mean_Fines': 33.3359255188229,
#    'Mean_KLS': 0.0384871543072503,
#    'Mean_KLSC': 0.00045989328955533,
#    'Mean_KLSC_Fines': 0.000174142429851697,
#    'Mean_LS': 0.375201477396599,
#    'Mean_Scald': 0,
#    'Time_Step': '1/09/1987'},
#   {'Area': 237180,
#    'Catchment_Name': 'SC #127',
#    'Cell_Count': 7906,
#    'FU_Name': 'Grazing Open',
#    'IntSCFU': 995,
#    'Mean_CFact': 0.051987228494669,
#    'Mean_Fines': 42.4863394889957,
#    'Mean_KLS': 0.0476455350366797,
#    'Mean_KLSC': 0.000346401245835773,
#    'Mean_KLSC_Fines': 0.000164140023030734,
#    'Mean_LS': 0.182135166258539,
#    'Mean_Scald': 0,
#    'Time_Step': '1/09/1987'},
#   {'Area': 99750,
#    'Catchment_Name': 'SC #49',
#    'Cell_Count': 3325,
#    'FU_Name': 'Conservation',
#    'IntSCFU': 97,
#    'Mean_CFact': 0.0315215003545067,
#    'Mean_Fines': 30.4583458646617,
#    'Mean_KLS': 0.0498345263157903,
#    'Mean_KLSC': 0.00753134510316044,
#    'Mean_KLSC_Fines': 0.0022768679976353,
#    'Mean_LS': 4.89696269857143,
#    'Mean_Scald': 0,
#    'Time_Step': '1/09/1987'},
#   {'Area': 21750,
#    'Catchment_Name': 'SC #90',
#    'Cell_Count': 725,
#    'FU_Name': 'Grazing Open',
#    'IntSCFU': 321,
#    'Mean_CFact': 0.0303389131354875,
#    'Mean_Fines': 35.5862068965517,
#    'Mean_KLS': 0.0437798620689653,
#    'Mean_KLSC': 0.00134411812412954,
#    'Mean_KLSC_Fines': 0.000467855930173432,
#    'Mean_LS': 1.37303790954482,
#    'Mean_Scald': 0,
#    'Time_Step': '1/09/1987'},
#   {'Area': 1891500,
#    'Catchment_Name': 'SC #83',
#    'Cell_Count': 63050,
#    'FU_Name': 'Forestry',
#    'IntSCFU': 132,
#    'Mean_CFact': 0.0396548029944822,
#    'Mean_Fines': 32.9780015860428,
#    'Mean_KLS': 0.0378746851704848,
# ...
#    'Cell_Count': 18386,
#    'FU_Name': 'Grazing Forested',
#    'IntSCFU': 1239,
#    'Mean_CFact': 0.0383275450600732,
#    'Mean_Fines': 28.7119403524419,
#    'Mean_KLS': 0.0502813042532189,
#    'Mean_KLSC': 0.00448586753351463,
#    'Mean_KLSC_Fines': 0.00124536782769307,
#    'Mean_LS': 2.14635237223164,
#    'Mean_Scald': 0,
#    'Time_Step': '1/09/1987'},
#   {'Area': 61590,
#    'Catchment_Name': 'SC #29',
#    'Cell_Count': 2053,
#    'FU_Name': 'Grazing Forested',
#    'IntSCFU': 506,
#    'Mean_CFact': 0.0267982502042416,
#    'Mean_Fines': 49.6639064783244,
#    'Mean_KLS': 0.0606487579152469,
#    'Mean_KLSC': 0.000461268843152274,
#    'Mean_KLSC_Fines': 0.000218498249915652,
#    'Mean_LS': 0.452975706176298,
#    'Mean_Scald': 0,
#    'Time_Step': '1/09/1987'},
#   {'Area': 115380,
#    'Catchment_Name': '',
#    'Cell_Count': 3846,
#    'FU_Name': '',
#    'IntSCFU': 533,
#    'Mean_CFact': 0.04502311499353,
#    'Mean_Fines': 33.6708268330733,
#    'Mean_KLS': 0.0568263130525243,
#    'Mean_KLSC': 0.00113286215226599,
#    'Mean_KLSC_Fines': 0.000430109207322872,
#    'Mean_LS': 0.505321658663546,
#    'Mean_Scald': 0,
#    'Time_Step': '1/09/1987'},
#   {'Area': 80610,
#    'Catchment_Name': 'SC #57',
#    'Cell_Count': 2687,
#    'FU_Name': 'Grazing Forested',
#    'IntSCFU': 566,
#    'Mean_CFact': 0.0385558201718603,
#    'Mean_Fines': 45.1574246371418,
#    'Mean_KLS': 0.0614941198362465,
#    'Mean_KLSC': 0.0028526038541411,
#    'Mean_KLSC_Fines': 0.00128239727767046,
#    'Mean_LS': 1.1281223879754,
#    'Mean_Scald': 0,
#    'Time_Step': '1/09/1987'},
#   {'Area': 31740,
#    'Catchment_Name': '',
#    'Cell_Count': 1058,
#    'FU_Name': '',
#    'IntSCFU': 599,
#    'Mean_CFact': 0.150295258408574,
#    'Mean_Fines': 52.5094517958412,
#    'Mean_KLS': 0.0641549149338373,
#    'Mean_KLSC': 0.00196996698154989,
#    'Mean_KLSC_Fines': 0.00100983331862787,
#    'Mean_LS': 0.249581011181476,
#    'Mean_Scald': 0,
#    'Time_Step': '1/09/1987'},
#   {'Area': 32160,
#    'Catchment_Name': '',
#    'Cell_Count': 1072,
#    'FU_Name': '',
#    'IntSCFU': 632,
#    'Mean_CFact': 0.0564523519545884,
#    'Mean_Fines': 37.4925373134328,
#    'Mean_KLS': 0.0579182835820899,
#    'Mean_KLSC': 0.00227796016340897,
#    'Mean_KLSC_Fines': 0.000958464668712816,
#    'Mean_LS': 0.889849856958955,
#    'Mean_Scald': 0,
#    'Time_Step': '1/09/1987'},
#   {'Area': 1020,
#    'Catchment_Name': 'SC #78',
#    'Cell_Count': 34,
#    'FU_Name': 'Conservation',
#    'IntSCFU': 665,
#    'Mean_CFact': 0.013117059284602,
#    'Mean_Fines': 30.2058823529412,
#    'Mean_KLS': 0.0495558823529412,
#    'Mean_KLSC': 0.000349393667685239,
#    'Mean_KLSC_Fines': 0.000104930154421257,
#    'Mean_LS': 0.601054830588235,
#    'Mean_Scald': 0,
#    'Time_Step': '1/09/1987'},
#   {'Area': 39540,
#    'Catchment_Name': '',
#    'Cell_Count': 1318,
#    'FU_Name': '',
#    'IntSCFU': 698,
#    'Mean_CFact': 0.0563129809836448,
#    'Mean_Fines': 43.9764795144158,
#    'Mean_KLS': 0.0586218512898324,
#    'Mean_KLSC': 0.000279997902608999,
#    'Mean_KLSC_Fines': 0.000122373574221582,
#    'Mean_LS': 0.0866703834218524,
#    'Mean_Scald': 0,
#    'Time_Step': '1/09/1987'},
#   {'Area': 66840,
#    'Catchment_Name': 'SC #146',
#    'Cell_Count': 2228,
#    'FU_Name': 'Grazing Open',
#    'IntSCFU': 53,
#    'Mean_CFact': 0.0512722158554567,
#    'Mean_Fines': 32.9605026929982,
#    'Mean_KLS': 0.0567118491921004,
#    'Mean_KLSC': 0.000807668865749053,
#    'Mean_KLSC_Fines': 0.000317095803554321,
#    'Mean_LS': 0.294534508828546,
#    'Mean_Scald': 0,
#    'Time_Step': '1/09/1987'},
#   {'Area': 690,
#    'Catchment_Name': '',
#    'Cell_Count': 23,
#    'FU_Name': '',
#    'IntSCFU': 764,
#    'Mean_CFact': 0.14283397000121,
#    'Mean_Fines': 64,
#    'Mean_KLS': 0.0872,
#    'Mean_KLSC': 0.000709940843533019,
#    'Mean_KLSC_Fines': 0.000454362139861132,
#    'Mean_LS': 0.05699991,
#    'Mean_Scald': 0,
#    'Time_Step': '1/09/1987'},
#   {'Area': 393720,
#    'Catchment_Name': '',
#    'Cell_Count': 13124,
#    'FU_Name': '',
#    'IntSCFU': 797,
#    'Mean_CFact': 0.0899316451726019,
#    'Mean_Fines': 32.8357208168241,
#    'Mean_KLS': 0.0618564766839311,
#    'Mean_KLSC': 0.000332204742835265,
#    'Mean_KLSC_Fines': 0.000104607581488378,
#    'Mean_LS': 0.0711079984829018,
#    'Mean_Scald': 0,
#    'Time_Step': '1/09/1987'},
#   {'Area': 167700,
#    'Catchment_Name': 'SC #103',
#    'Cell_Count': 5590,
#    'FU_Name': 'Grazing Open',
#    'IntSCFU': 830,
#    'Mean_CFact': 0.0515783988513312,
#    'Mean_Fines': 34.6293381037567,
#    'Mean_KLS': 0.0681396243291586,
#    'Mean_KLSC': 0.000468873269171457,
#    'Mean_KLSC_Fines': 0.000162680267199309,
#    'Mean_LS': 0.170172447613593,
#    'Mean_Scald': 0,
#    'Time_Step': '1/09/1987'},
#   {'Area': 256680,
#    'Catchment_Name': 'SC #98',
#    'Cell_Count': 8556,
#    'FU_Name': 'Grazing Forested',
#    'IntSCFU': 863,
#    'Mean_CFact': 0.0177236001290052,
#    'Mean_Fines': 47.6944834034596,
#    'Mean_KLS': 0.0773592332865787,
#    'Mean_KLSC': 0.00114260638139826,
#    'Mean_KLSC_Fines': 0.000520119176200108,
#    'Mean_LS': 0.621552501978718,
#    'Mean_Scald': 0,
#    'Time_Step': '1/09/1987'},
#   {'Area': 9270,
#    'Catchment_Name': '',
#    'Cell_Count': 309,
#    'FU_Name': '',
#    'IntSCFU': 896,
#    'Mean_CFact': 0.0770882078970882,
#    'Mean_Fines': 48.3624595469256,
#    'Mean_KLS': 0.0589754045307445,
#    'Mean_KLSC': 0.00189708934262738,
#    'Mean_KLSC_Fines': 0.000896985724248203,
#    'Mean_LS': 0.628334637637541,
#    'Mean_Scald': 0,
#    'Time_Step': '1/09/1987'},
#   {'Area': 23100,
#    'Catchment_Name': 'SC #90200',
#    'Cell_Count': 770,
#    'FU_Name': 'Conservation',
#    'IntSCFU': 929,
#    'Mean_CFact': 0.0816954923436868,
#    'Mean_Fines': 42.2233766233766,
#    'Mean_KLS': 0.0656963636363634,
#    'Mean_KLSC': 0.000521572816922717,
#    'Mean_KLSC_Fines': 0.000209105513739887,
#    'Mean_LS': 0.14844387764935,
#    'Mean_Scald': 0,
#    'Time_Step': '1/09/1987'},
#   {'Area': 67350,
#    'Catchment_Name': '',
#    'Cell_Count': 2245,
#    'FU_Name': '',
#    'IntSCFU': 962,
#    'Mean_CFact': 0.121514788522636,
#    'Mean_Fines': 45.8841870824053,
#    'Mean_KLS': 0.0752784855233845,
#    'Mean_KLSC': 0.000667611541309431,
#    'Mean_KLSC_Fines': 0.000320488351771093,
#    'Mean_LS': 0.0744777885746113,
#    'Mean_Scald': 0,
#    'Time_Step': '1/09/1987'},
#   {'Area': 110850,
#    'Catchment_Name': '',
#    'Cell_Count': 3695,
#    'FU_Name': '',
#    'IntSCFU': 75,
#    'Mean_CFact': 0.0937140232485156,
#    'Mean_Fines': 55.2416779431664,
#    'Mean_KLS': 0.0820560487144783,
#    'Mean_KLSC': 0.00035570335028939,
#    'Mean_KLSC_Fines': 0.000185489124681842,
#    'Mean_LS': 0.058289004192153,
#    'Mean_Scald': 0,
#    'Time_Step': '1/09/1987'},
#   {'Area': 241830,
#    'Catchment_Name': 'SC #135',
#    'Cell_Count': 8061,
#    'FU_Name': 'Grazing Open',
#    'IntSCFU': 1032,
#    'Mean_CFact': 0.0448071989030937,
#    'Mean_Fines': 26.5753628582062,
#    'Mean_KLS': 0.0406990323781158,
#    'Mean_KLSC': 0.000320368131593625,
#    'Mean_KLSC_Fines': 8.02786883089002e-05,
#    'Mean_LS': 0.292283593538029,
#    'Mean_Scald': 0,
#    'Time_Step': '1/09/1987'},
#   {'Area': 171300,
#    'Catchment_Name': '',
#    'Cell_Count': 5710,
#    'FU_Name': '',
#    'IntSCFU': 1098,
#    'Mean_CFact': 0.123694439173061,
#    'Mean_Fines': 46.644092178634,
#    'Mean_KLS': 0.0508273502626955,
#    'Mean_KLSC': 0.00153147443370796,
#    'Mean_KLSC_Fines': 0.000718648127221344,
#    'Mean_LS': 0.362975231824878,
#    'Mean_Scald': 0,
#    'Time_Step': '1/09/1987'},
#   {'Area': 7530,
#    'Catchment_Name': 'SC #90201',
#    'Cell_Count': 251,
#    'FU_Name': 'Grazing Forested',
#    'IntSCFU': 1164,
#    'Mean_CFact': 0.0220808822372223,
#    'Mean_Fines': 51.1394422310757,
#    'Mean_KLS': 0.0822617529880482,
#    'Mean_KLSC': 0.000164501607515769,
#    'Mean_KLSC_Fines': 8.34115408219453e-05,
#    'Mean_LS': 0.0964433637450198,
#    'Mean_Scald': 0,
#    'Time_Step': '1/09/1987'},
#   {'Area': 7260,
#    'Catchment_Name': '',
#    'Cell_Count': 242,
#    'FU_Name': '',
#    'IntSCFU': 1230,
#    'Mean_CFact': 0.0339931518374365,
#    'Mean_Fines': 29.7933884297521,
#    'Mean_KLS': 0.0483603305785123,
#    'Mean_KLSC': 0.000189158948830419,
#    'Mean_KLSC_Fines': 5.47117056801355e-05,
#    'Mean_LS': 0.181272182438017,
#    'Mean_Scald': 0,
#    'Time_Step': '1/09/1987'},
#   {'Area': 7440,
#    'Catchment_Name': '',
#    'Cell_Count': 248,
#    'FU_Name': '',
#    'IntSCFU': 1283,
#    'Mean_CFact': 0.0423386893854777,
#    'Mean_Fines': 38.991935483871,
#    'Mean_KLS': 0.0581782258064515,
#    'Mean_KLSC': 0.000143394407621471,
#    'Mean_KLSC_Fines': 6.19900368076981e-05,
#    'Mean_LS': 0.05699991,
#    'Mean_Scald': 0,
#    'Time_Step': '1/09/1987'},
#   {'Area': 49530,
#    'Catchment_Name': 'SC #52',
#    'Cell_Count': 1651,
#    'FU_Name': 'Conservation',
#    'IntSCFU': 108,
#    'Mean_CFact': 0.0248547297764766,
#    'Mean_Fines': 42.7540884312538,
#    'Mean_KLS': 0.0576907934585089,
#    'Mean_KLSC': 0.00312342065241497,
#    'Mean_KLSC_Fines': 0.00152001870943652,
#    'Mean_LS': 2.45558289732887,
#    'Mean_Scald': 0,
#    'Time_Step': '1/09/1987'},
#   {'Area': 7350,
#    'Catchment_Name': '',
#    'Cell_Count': 245,
#    'FU_Name': '',
#    'IntSCFU': 686,
#    'Mean_CFact': 0.149662547507228,
#    'Mean_Fines': 36.1224489795918,
#    'Mean_KLS': 0.0630983673469389,
#    'Mean_KLSC': 0.000520030470499576,
#    'Mean_KLSC_Fines': 0.000177342588336776,
#    'Mean_LS': 0.05699991,
#    'Mean_Scald': 0,
#    'Time_Step': '1/09/1987'},
#   {'Area': 575850,
#    'Catchment_Name': 'SC #86',
#    'Cell_Count': 19195,
#    'FU_Name': 'Forestry',
#    'IntSCFU': 154,
#    'Mean_CFact': 0.0432299181873102,
#    'Mean_Fines': 31.4742380828341,
#    'Mean_KLS': 0.0546048866892338,
#    'Mean_KLSC': 0.00814715949421236,
#    'Mean_KLSC_Fines': 0.00299838964281077,
#    'Mean_LS': 3.53318992711852,
#    'Mean_Scald': 0,
#    'Time_Step': '1/09/1987'},
#   {'Area': 103740,
#    'Catchment_Name': 'SC #38',
#    'Cell_Count': 3458,
#    'FU_Name': 'Conservation',
#    'IntSCFU': 13,
#    'Mean_CFact': 0.0591106976116073,
#    'Mean_Fines': 30.9971081550029,
#    'Mean_KLS': 0.0479359167148633,
#    'Mean_KLSC': 0.0117601638320528,
#    'Mean_KLSC_Fines': 0.00373281921677243,
#    'Mean_LS': 4.1009917926258,
#    'Mean_Scald': 0,
#    'Time_Step': '1/09/1987'},
#   {'Area': 57750,
#    'Catchment_Name': '',
#    'Cell_Count': 1925,
#    'FU_Name': '',
#    'IntSCFU': 187,
#    'Mean_CFact': 0.0268162675426862,
#    'Mean_Fines': 42.3672727272727,
#    'Mean_KLS': 0.0566768311688308,
#    'Mean_KLSC': 0.000105868654465347,
#    'Mean_KLSC_Fines': 4.17096656731327e-05,
#    'Mean_LS': 0.0755613561506506,
#    'Mean_Scald': 0,
#    'Time_Step': '1/09/1987'},
#   {'Area': 255690,
#    'Catchment_Name': '',
#    'Cell_Count': 8523,
#    'FU_Name': '',
#    'IntSCFU': 809,
#    'Mean_CFact': 0.144124768391251,
#    'Mean_Fines': 41.6793382611756,
#    'Mean_KLS': 0.0655647776604504,
#    'Mean_KLSC': 0.000696459489383167,
#    'Mean_KLSC_Fines': 0.00030691409929449,
#    'Mean_LS': 0.0886039537791659,
#    'Mean_Scald': 0,
#    'Time_Step': '1/09/1987'},
#   {'Area': 701160,
#    'Catchment_Name': 'SC #7',
#    'Cell_Count': 23372,
#    'FU_Name': 'Grazing Open',
#    'IntSCFU': 220,
#    'Mean_CFact': 0.0808842816236205,
#    'Mean_Fines': 29.1983570083861,
#    'Mean_KLS': 0.0489981302413162,
#    'Mean_KLSC': 0.000531321471370512,
#    'Mean_KLSC_Fines': 0.000174116505412038,
#    'Mean_LS': 0.150022921891564,
#    'Mean_Scald': 0,
#    'Time_Step': '1/09/1987'},
#   {'Area': 733320,
#    'Catchment_Name': 'SC #46',
#    'Cell_Count': 24444,
#    'FU_Name': 'Grazing Open',
#    'IntSCFU': 253,
#    'Mean_CFact': 0.0423522616868875,
#    'Mean_Fines': 41.9945999018164,
#    'Mean_KLS': 0.0591025773195844,
#    'Mean_KLSC': 0.000891040539228342,
#    'Mean_KLSC_Fines': 0.000373167762948037,
#    'Mean_LS': 0.435156816493619,
#    'Mean_Scald': 0,
#    'Time_Step': '1/09/1987'},
#   {'Area': 222030,
#    'Catchment_Name': '',
#    'Cell_Count': 7401,
#    'FU_Name': '',
#    'IntSCFU': 283,
#    'Mean_CFact': 0.103059315094036,
#    'Mean_Fines': 37.7200378327253,
#    'Mean_KLS': 0.0586805296581542,
#    'Mean_KLSC': 0.00090035936357848,
#    'Mean_KLSC_Fines': 0.000351062296559903,
#    'Mean_LS': 0.165736314783132,
#    'Mean_Scald': 0,
#    'Time_Step': '1/09/1987'},
#   {'Area': 80730,
#    'Catchment_Name': '',
#    'Cell_Count': 2691,
#    'FU_Name': '',
#    'IntSCFU': 1081,
#    'Mean_CFact': 0.147585725162243,
#    'Mean_Fines': 44.5414344109996,
#    'Mean_KLS': 0.0549440728353782,
#    'Mean_KLSC': 0.00266085504377991,
#    'Mean_KLSC_Fines': 0.00133443663203056,
#    'Mean_LS': 0.499728911460453,
#    'Mean_Scald': 0,
#    'Time_Step': '1/09/1987'},
#   {'Area': 25440,
#    'Catchment_Name': '',
#    'Cell_Count': 848,
#    'FU_Name': '',
#    'IntSCFU': 316,
#    'Mean_CFact': 0.05411490569504,
#    'Mean_Fines': 47.3042452830189,
#    'Mean_KLS': 0.060391745283019,
#    'Mean_KLSC': 0.00334113957647768,
#    'Mean_KLSC_Fines': 0.00178364224680974,
#    'Mean_LS': 1.13514100121462,
#    'Mean_Scald': 0,
#    'Time_Step': '1/09/1987'},
#   {'Area': 336810,
#    'Catchment_Name': 'SC #90192',
#    'Cell_Count': 11227,
#    'FU_Name': 'Grazing Forested',
#    'IntSCFU': 1213,
#    'Mean_CFact': 0.0281415375068115,
#    'Mean_Fines': 25.0691190879131,
#    'Mean_KLS': 0.0416226863810399,
#    'Mean_KLSC': 0.000175896324502699,
#    'Mean_KLSC_Fines': 4.67773127156971e-05,
#    'Mean_LS': 0.241173089273113,
#    'Mean_Scald': 0,
#    'Time_Step': '1/09/1987'},
#   {'Area': 20730,
#    'Catchment_Name': '',
#    'Cell_Count': 691,
#    'FU_Name': '',
#    'IntSCFU': 349,
#    'Mean_CFact': 0.0216436721121706,
#    'Mean_Fines': 37.5788712011577,
#    'Mean_KLS': 0.0558111432706225,
#    'Mean_KLSC': 0.000353556039860934,
#    'Mean_KLSC_Fines': 0.000124682505550746,
#    'Mean_LS': 0.287549748422576,
#    'Mean_Scald': 0,
#    'Time_Step': '1/09/1987'},
#   {'Area': 468660,
#    'Catchment_Name': 'SC #85',
#    'Cell_Count': 15622,
#    'FU_Name': 'Grazing Forested',
#    'IntSCFU': 294,
#    'Mean_CFact': 0.0324356498990152,
#    'Mean_Fines': 28.2235309179362,
#    'Mean_KLS': 0.0438845986429414,
#    'Mean_KLSC': 0.00442099811308941,
#    'Mean_KLSC_Fines': 0.00126395358261447,
#    'Mean_LS': 2.61913895723403,
#    'Mean_Scald': 0,
#    'Time_Step': '1/09/1987'},
#   {'Area': 540690,
#    'Catchment_Name': 'SC #89',
#    'Cell_Count': 18023,
#    'FU_Name': 'Forestry',
#    'IntSCFU': 382,
#    'Mean_CFact': 0.0393585554675311,
#    'Mean_Fines': 30.5965710481052,
#    'Mean_KLS': 0.0349050269100542,
#    'Mean_KLSC': 0.0068250663324217,
#    'Mean_KLSC_Fines': 0.00215922217086272,
#    'Mean_LS': 5.07543649222272,
#    'Mean_Scald': 0,
#    'Time_Step': '1/09/1987'},
#   {'Area': 297390,
#    'Catchment_Name': 'SC #32',
#    'Cell_Count': 9913,
#    'FU_Name': 'Conservation',
#    'IntSCFU': 415,
#    'Mean_CFact': 0.0319057722954767,
#    'Mean_Fines': 46.9072934530415,
#    'Mean_KLS': 0.0601495611822841,
#    'Mean_KLSC': 0.00295976414321063,
#    'Mean_KLSC_Fines': 0.00141760692555979,
#    'Mean_LS': 2.31083211580862,
#    'Mean_Scald': 0,
#    'Time_Step': '1/09/1987'},
#   {'Area': 374550,
#    'Catchment_Name': '',
#    'Cell_Count': 12485,
#    'FU_Name': '',
#    'IntSCFU': 448,
#    'Mean_CFact': 0.0838009284707782,
#    'Mean_Fines': 44.3388065678815,
#    'Mean_KLS': 0.0607473928714484,
#    'Mean_KLSC': 0.000693120017546751,
#    'Mean_KLSC_Fines': 0.000295113420591874,
#    'Mean_LS': 0.157304221385675,
#    'Mean_Scald': 0,
#    'Time_Step': '1/09/1987'},
#   ...],
#  'globalAverageResultsTable': [{'Mean_CFact': 0.062860392774341,
#    'Mean_Fines': 39.3358868521206,
#    'Mean_KLS': 0.0573313388664099,
#    'Mean_KLSC': 0.00173605339947283,
#    'Mean_KLSC_Fines': 0.000686394681569301,
#    'Mean_LS': 0.854292609142272,
#    'Mean_Scald': 0,
#    'Time_Step': '1/09/1987'},
#   {'Mean_CFact': 0.0715309118004192,
#    'Mean_Fines': 39.355806015412,
#    'Mean_KLS': 0.0573028218818249,
#    'Mean_KLSC': 0.00209794593217943,
#    'Mean_KLSC_Fines': 0.000841554353743163,
#    'Mean_LS': 0.852825724257999,
#    'Mean_Scald': 0,
#    'Time_Step': '1/12/1987'},
#   {'Mean_CFact': 0.031687248385306,
#    'Mean_Fines': 39.3875680522513,
#    'Mean_KLS': 0.0573012068197877,
#    'Mean_KLSC': 0.00116491835256965,
#    'Mean_KLSC_Fines': 0.000468628093282005,
#    'Mean_LS': 0.862573648268337,
#    'Mean_Scald': 0,
#    'Time_Step': '1/03/1988'},
#   {'Mean_CFact': 0.0291270625055215,
#    'Mean_Fines': 39.3582891935336,
#    'Mean_KLS': 0.0573414875769849,
#    'Mean_KLSC': 0.000854970843711352,
#    'Mean_KLSC_Fines': 0.000340313970016796,
#    'Mean_LS': 0.865210602678606,
#    'Mean_Scald': 0,
#    'Time_Step': '1/06/1988'}]}

# %%
df = pd.DataFrame(result['ResultsTable'])

# %%
df.to_csv('ResultsTable.csv',index=False)

# %%
pd.read_csv('ResultsTable.csv')
# Out:
#             Area Catchment_Name  Cell_Count           FU_Name  IntSCFU  \
# 0        34080.0        SC #159      1136.0      Conservation     1155
# 1       323250.0         SC #22     10775.0      Grazing Open      124
# 2        86100.0        SC #138      2870.0      Grazing Open     1135
# 3        78990.0            NaN      2633.0               NaN      153
# 4        35100.0            NaN      1170.0               NaN      186
# 5       154320.0        SC #158      5144.0      Grazing Open      931
# 6       822900.0         SC #10     27430.0  Grazing Forested       15
# 7        20220.0            NaN       674.0               NaN      219
# 8       204960.0            NaN      6832.0               NaN      651
# 9        35490.0         SC #46      1183.0          Forestry      252
# 10       14160.0        SC #117       472.0      Grazing Open     1063
# 11       57180.0        SC #137      1906.0      Grazing Open     1183
# 12        4500.0            NaN       150.0               NaN     1073
# 13        3390.0        SC #132       113.0      Conservation     1139
# 14       21540.0        SC #130       718.0      Conservation     1205
# 15      463200.0          SC #2     15440.0  Grazing Forested        4
# 16        1320.0         SC #26        44.0  Grazing Forested      380
# 17        9060.0            NaN       302.0               NaN      413
# 18        2880.0         SC #85        96.0      Grazing Open      296
# 19        1860.0            NaN        62.0               NaN      446
# 20      233100.0            NaN      7770.0               NaN     1067
# 21       33870.0            NaN      1129.0               NaN      479
# 22       56280.0        SC #155      1876.0          Forestry      363
# 23          60.0         SC #30         2.0      Conservation      512
# 24       25050.0            NaN       835.0               NaN      545
# 25       51360.0      SC #90172      1712.0  Grazing Forested      578
# 26       81480.0            NaN      2716.0               NaN      611
# 27         510.0            NaN        17.0               NaN      644
# 28       87930.0         SC #67      2931.0  Grazing Forested      677
# 29        5640.0        SC #128       188.0      Grazing Open     1175
# ...          ...            ...         ...               ...      ...
# 119094       NaN      SC #90197         NaN      Grazing Open     1279
# 119095       NaN      SC #90197         NaN      Grazing Open     1279
# 119096       NaN      SC #90197         NaN      Grazing Open     1279
# 119097       NaN      SC #90197         NaN      Grazing Open     1279
# 119098       NaN      SC #90197         NaN      Grazing Open     1279
# 119099       NaN      SC #90197         NaN      Grazing Open     1279
# 119100       NaN      SC #90197         NaN      Grazing Open     1279
# 119101       NaN      SC #90197         NaN      Grazing Open     1279
# 119102       NaN      SC #90197         NaN      Grazing Open     1279
# 119103       NaN      SC #90197         NaN      Grazing Open     1279
# 119104       NaN      SC #90197         NaN      Grazing Open     1279
# 119105       NaN      SC #90197         NaN      Grazing Open     1279
# 119106       NaN      SC #90197         NaN      Grazing Open     1279
# 119107       NaN      SC #90197         NaN      Grazing Open     1279
# 119108       NaN      SC #90197         NaN      Grazing Open     1279
# 119109       NaN      SC #90197         NaN      Grazing Open     1279
# 119110       NaN      SC #90197         NaN      Grazing Open     1279
# 119111       NaN      SC #90197         NaN      Grazing Open     1279
# 119112       NaN      SC #90197         NaN      Grazing Open     1279
# 119113       NaN      SC #90197         NaN      Grazing Open     1279
# 119114       NaN      SC #90197         NaN      Grazing Open     1279
# 119115       NaN      SC #90197         NaN      Grazing Open     1279
# 119116       NaN      SC #90197         NaN      Grazing Open     1279
# 119117       NaN      SC #90197         NaN      Grazing Open     1279
# 119118       NaN      SC #90197         NaN      Grazing Open     1279
# 119119       NaN      SC #90197         NaN      Grazing Open     1279
# 119120       NaN      SC #90197         NaN      Grazing Open     1279
# 119121       NaN      SC #90197         NaN      Grazing Open     1279
# 119122       NaN      SC #90197         NaN      Grazing Open     1279
# 119123       NaN      SC #90197         NaN      Grazing Open     1279
#
#         Mean_CFact  Mean_Fines  Mean_KLS  Mean_KLSC  Mean_KLSC_Fines  \
# 0         0.044214   28.831866  0.038842   0.007421         0.002080
# 1         0.031191   35.261067  0.054858   0.000553         0.000192
# 2         0.026816   28.374913  0.040178   0.000237         0.000067
# 3         0.117597   47.180403  0.071660   0.000433         0.000206
# 4         0.088478   43.358120  0.064967   0.000344         0.000168
# 5         0.016096   41.218507  0.058910   0.000331         0.000114
# 6         0.068233   35.436785  0.055350   0.002032         0.000823
# 7         0.038928   32.894659  0.049710   0.000110         0.000036
# 8         0.098792   44.775761  0.070041   0.000413         0.000210
# 9         0.026453   30.843618  0.047485   0.000440         0.000161
# 10        0.058445   49.980932  0.061638   0.000199         0.000102
# 11        0.040991   29.911857  0.046743   0.000194         0.000057
# 12        0.082099   49.000000  0.070067   0.000333         0.000168
# 13        0.066188   29.230088  0.046218   0.000214         0.000057
# 14        0.052137   34.445682  0.058390   0.000174         0.000059
# 15        0.078217   33.431218  0.051477   0.001601         0.000480
# 16        0.022533   48.636364  0.074805   0.000095         0.000047
# 17        0.106871   32.009934  0.059220   0.000359         0.000115
# 18        0.043628   28.000000  0.043487   0.010683         0.002991
# 19        0.102877   40.403226  0.058337   0.004514         0.001990
# 20        0.104758   29.880824  0.038782   0.000501         0.000137
# 21        0.044332   49.837910  0.051337   0.000127         0.000064
# 22        0.037387   27.959488  0.037089   0.004172         0.001166
# 23        0.015130   34.000000  0.053400   0.000046         0.000016
# 24        0.087101   48.790419  0.067802   0.000426         0.000215
# 25        0.028345   45.634930  0.058459   0.001852         0.000823
# 26        0.083138   45.541973  0.067262   0.001676         0.000815
# 27        0.089048   60.000000  0.086635   0.000448         0.000277
# 28        0.019959   65.065507  0.066452   0.001707         0.001131
# 29        0.052616   47.372340  0.062073   0.000190         0.000087
# ...            ...         ...       ...        ...              ...
# 119094    0.037726   25.570845  0.045266   0.000290         0.000085
# 119095    0.037726   25.570845  0.045266   0.000290         0.000085
# 119096    0.037726   25.570845  0.045266   0.000290         0.000085
# 119097    0.037726   25.570845  0.045266   0.000290         0.000085
# 119098    0.037726   25.570845  0.045266   0.000290         0.000085
# 119099    0.037726   25.570845  0.045266   0.000290         0.000085
# 119100    0.037726   25.570845  0.045266   0.000290         0.000085
# 119101    0.037726   25.570845  0.045266   0.000290         0.000085
# 119102    0.037726   25.570845  0.045266   0.000290         0.000085
# 119103    0.037726   25.570845  0.045266   0.000290         0.000085
# 119104    0.037726   25.570845  0.045266   0.000290         0.000085
# 119105    0.037726   25.570845  0.045266   0.000290         0.000085
# 119106    0.037726   25.570845  0.045266   0.000290         0.000085
# 119107    0.037726   25.570845  0.045266   0.000290         0.000085
# 119108    0.037726   25.570845  0.045266   0.000290         0.000085
# 119109    0.037726   25.570845  0.045266   0.000290         0.000085
# 119110    0.037726   25.570845  0.045266   0.000290         0.000085
# 119111    0.037726   25.570845  0.045266   0.000290         0.000085
# 119112    0.037726   25.570845  0.045266   0.000290         0.000085
# 119113    0.037726   25.570845  0.045266   0.000290         0.000085
# 119114    0.037726   25.570845  0.045266   0.000290         0.000085
# 119115    0.037726   25.570845  0.045266   0.000290         0.000085
# 119116    0.037726   25.570845  0.045266   0.000290         0.000085
# 119117    0.037726   25.570845  0.045266   0.000290         0.000085
# 119118    0.037726   25.570845  0.045266   0.000290         0.000085
# 119119    0.037726   25.570845  0.045266   0.000290         0.000085
# 119120    0.037726   25.570845  0.045266   0.000290         0.000085
# 119121    0.037726   25.570845  0.045266   0.000290         0.000085
# 119122    0.037726   25.570845  0.045266   0.000290         0.000085
# 119123    0.037726   25.570845  0.045266   0.000290         0.000085
#
#          Mean_LS  Mean_Scald  Time_Step
# 0       4.842483           0  1/09/1987
# 1       0.370254           0  1/09/1987
# 2       0.289991           0  1/09/1987
# 3       0.057432           0  1/09/1987
# 4       0.062945           0  1/09/1987
# 5       0.654198           0  1/09/1987
# 6       0.560805           0  1/09/1987
# 7       0.057000           0  1/09/1987
# 8       0.057027           0  1/09/1987
# 9       0.230199           0  1/09/1987
# 10      0.057000           0  1/09/1987
# 11      0.143329           0  1/09/1987
# 12      0.057000           0  1/09/1987
# 13      0.069532           0  1/09/1987
# 14      0.057000           0  1/09/1987
# 15      0.482812           0  1/09/1987
# 16      0.057000           0  1/09/1987
# 17      0.057000           0  1/09/1987
# 18      4.630179           0  1/09/1987
# 19      0.928637           0  1/09/1987
# 20      0.148020           0  1/09/1987
# 21      0.057000           0  1/09/1987
# 22      2.967922           0  1/09/1987
# 23      0.057000           0  1/09/1987
# 24      0.090747           0  1/09/1987
# 25      1.109557           0  1/09/1987
# 26      0.560076           0  1/09/1987
# 27      0.057000           0  1/09/1987
# 28      1.419952           0  1/09/1987
# 29      0.058337           0  1/09/1987
# ...          ...         ...        ...
# 119094  0.152165           0  1/09/2007
# 119095  0.152165           0  1/12/2007
# 119096  0.152165           0  1/03/2008
# 119097  0.152165           0  1/06/2008
# 119098  0.152165           0  1/09/2008
# 119099  0.152165           0  1/12/2008
# 119100  0.152165           0  1/03/2009
# 119101  0.152165           0  1/06/2009
# 119102  0.152165           0  1/09/2009
# 119103  0.152165           0  1/12/2009
# 119104  0.152165           0  1/03/2010
# 119105  0.152165           0  1/06/2010
# 119106  0.152165           0  1/09/2010
# 119107  0.152165           0  1/12/2010
# 119108  0.152165           0  1/03/2011
# 119109  0.152165           0  1/06/2011
# 119110  0.152165           0  1/09/2011
# 119111  0.152165           0  1/12/2011
# 119112  0.152165           0  1/03/2012
# 119113  0.152165           0  1/06/2012
# 119114  0.152165           0  1/09/2012
# 119115  0.152165           0  1/12/2012
# 119116  0.152165           0  1/03/2013
# 119117  0.152165           0  1/06/2013
# 119118  0.152165           0  1/09/2013
# 119119  0.152165           0  1/12/2013
# 119120  0.152165           0  1/03/2014
# 119121  0.152165           0  1/06/2014
# 119122  0.152165           0  1/09/2014
# 119123  0.152165           0  1/12/2014
#
# [119124 rows x 13 columns]

# %%
v.shutdown()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-33-cf23e14766d2> in <module>()
# ----> 1 v.shutdown()
#
# AttributeError: 'Veneer' object has no attribute 'shutdown'
