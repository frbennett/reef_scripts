# %%
import veneer
import os
import pandas as pd
import numpy as np
import sys
#sys.path.append('..\\..\\..\\dsed-py\\dsed-py\\dsed')
#from dsed.testing.preprocessors import *
import dsed
from dsed import preprocessors
#from dsed.preprocessors import raster_path
# Out:
# climate Dynamic_SedNet.Parameterisation.Models.ClimateCollationModel
# gully Dynamic_SedNet.Parameterisation.Models.GullyParameterisationModel
# usle Dynamic_SedNet.Parameterisation.Models.CoverTimeSeries_SpatialPreprocessorModel
# gbrusle GBR_DynSed_Extension.Parameterisation.Models.GBRUSLECoverTimeSeriesSpatialPreprocessorModel
# lewis GBR_DynSed_Extension.Parameterisation.Models.LewisTrappingParameterisationModel

# %%
v = veneer.Veneer()

# %%
veneer.general.PRINT_SCRIPTS=False

# %%
parameters = {
    'Path_klsRaster':'"P:/projects/eReefs/GBRF_SpeedScenarios/FitzStuff/cfact/topoSoil/fi_klsrckfact_rc2018.tif"',
    'Path_lsRaster':'""',
    'Path_ClayPercRaster':'"P:/projects/eReefs/GBRF_SpeedScenarios/FitzStuff/cfact/topoSoil/fz_cs_surf.tif"',
    'Path_Intersected':'"P:/projects/eReefs/GBRF_SpeedScenarios/FitzStuff/cfact/FI_IntSCFU_ForGBRF.shp"',
    'Path_CFactorDirectory':'"P:/projects/eReefs/GBRF_SpeedScenarios/FitzStuff/cfact/rasters/short"',
    'DatePattern':'"xxxyyyymm"',
    'FUtoParameterise':['Grazing Open','Grazing Forested'],
    'Path_TSOutputDirectory':'"P:/projects/eReefs/GBRF_SpeedScenarios/FitzStuff/cfact/RobTimeSeries"',
    'Cover_Type':'"Calculated C Factor"',
    'useInternalIntersectedPolys':False,
    'updateModels':False,
    'useCombinedKLS':True,
    'maxThreads':8,
    'TemperalCoverType':'"TimeSeries"',
    'AnalysisTimeStep':'"Seasonal"',
    'requiredStartDateString':'"01/12/1979"',
    'requiredEndDateString':'"28/02/2019"',
    'managementPolysShapeLoc':'"P:/projects/eReefs/GBRF_SpeedScenarios/FitzStuff/cfact/FI_GrzDP_RC10_WithHillslope_LandTypes_GBRF_D_bits.shp"',
    'paramAName':'"PARAM_A"',
    'paramBName':'"PARAM_B"'
}

# %%
preprocessor = preprocessors.run_gbrusle

# %%
UNUSED = []

# %%
type(parameters['FUtoParameterise'])==list
# Out:
# True

# %%
type(5),type(5.0),type('5')
# Out:
# (int, float, str)

# %%
defaults = preprocessors.gbrusle_default_params(v)
{k:v for k,v in defaults.items() if v is None and not k in parameters and not k in UNUSED}
# Out:
# {'Path_PercScaldRaster': None, 'Path_StaticKLSCFile': None}

# %%
#defaults
veneer.general.PRINT_SCRIPTS=False

# %%
veneer.general.PRINT_SCRIPTS=True
result = preprocessors.run_gbrusle(v,**parameters)
# Out:
# # Generated Script
# import GBR_DynSed_Extension.Parameterisation.Models.GBRUSLECoverTimeSeriesSpatialPreprocessorModel
# import clr
# clr.AddReference('System.Core')
# import System
# import FlowMatters.Source.Veneer.RemoteScripting.ScriptHelpers as H
# clr.ImportExtensions(System.Linq)
# from TIME.Core.Metadata import OutputAttribute
# result = []
# tmp = GBR_DynSed_Extension.Parameterisation.Models.GBRUSLECoverTimeSeriesSpatialPreprocessorModel()
# typeObject = tmp.GetType()
# for member in dir(tmp):
#   try:
#     if typeObject.GetMember(member)[0].IsDefined(OutputAttribute,True):
#       result.append(member)
#   except: pass
#
# import GBR_DynSed_Extension.Parameterisation.Models.GBRUSLECoverTimeSeriesSpatialPreprocessorModel as GBRUSLECoverTimeSeriesSpatialPreprocessorModel
# import Dynamic_SedNet.Tools.ToolsModel as ToolsModel
#
# p = GBRUSLECoverTimeSeriesSpatialPreprocessorModel()
# p.Scenario = scenario
# p.CatPolys = scenario.GeographicData.IntersectedSCFUPolygons[1]
# p.FuPolys = scenario.GeographicData.IntersectedSCFUPolygons[1]
# p.Path_klsRaster = "P:/projects/eReefs/GBRF_SpeedScenarios/FitzStuff/cfact/topoSoil/fi_klsrckfact_rc2018.tif"
# p.Path_lsRaster = ""
# p.Path_ClayPercRaster = "P:/projects/eReefs/GBRF_SpeedScenarios/FitzStuff/cfact/topoSoil/fz_cs_surf.tif"
# p.Path_Intersected = "P:/projects/eReefs/GBRF_SpeedScenarios/FitzStuff/cfact/FI_IntSCFU_ForGBRF.shp"
# p.Path_CFactorDirectory = "P:/projects/eReefs/GBRF_SpeedScenarios/FitzStuff/cfact/rasters/short"
# p.DatePattern = "xxxyyyymm"
# p.FUtoParameterise = tuple(['Grazing Open', 'Grazing Forested'])
# p.Path_TSOutputDirectory = "P:/projects/eReefs/GBRF_SpeedScenarios/FitzStuff/cfact/RobTimeSeries"
# p.useInternalIntersectedPolys = False
# p.updateModels = False
# p.useCombinedKLS = True
# p.maxThreads = 8
# p.TemperalCoverType = "TimeSeries"
# p.AnalysisTimeStep = "Seasonal"
# p.requiredStartDateString = "01/12/1979"
# p.requiredEndDateString = "28/02/2019"
# p.managementPolysShapeLoc = "P:/projects/eReefs/GBRF_SpeedScenarios/FitzStuff/cfact/FI_GrzDP_RC10_WithHillslope_LandTypes_GBRF_D_bits.shp"
# p.paramAName = "PARAM_A"
# p.paramBName = "PARAM_B"
# p.runTimeStep()
# result = {}
# result["ResultsTable"] = p.ResultsTable
# result["globalAverageResultsTable"] = p.globalAverageResultsTable

# %%
#result

# %%
df = pd.DataFrame(result['ResultsTable'])

# %%
df.to_csv('ResultsTableChange.csv',index=False)

# %%
pd.read_csv('ResultsTableChange.csv')
# Out:
#        Area Catchment_Name  Cell_Count           FU_Name  IntSCFU  Mean_CFact  \
# 0         0        SC #104           0  Grazing Forested        1    0.020226
# 1         0        SC #104           0  Grazing Forested        1    0.020226
# 2         0        SC #104           0  Grazing Forested        1    0.020226
# 3         0        SC #104           0  Grazing Forested        1    0.020226
# 4         0        SC #104           0  Grazing Forested        1    0.020226
# 5         0        SC #104           0  Grazing Forested        1    0.020226
# 6         0        SC #104           0  Grazing Forested        1    0.020226
# 7         0        SC #104           0  Grazing Forested        1    0.020226
# 8         0        SC #104           0  Grazing Forested        1    0.020226
# 9         0        SC #104           0  Grazing Forested        1    0.020226
# 10        0        SC #104           0  Grazing Forested        1    0.020226
# 11        0        SC #104           0  Grazing Forested        1    0.020226
# 12        0        SC #104           0  Grazing Forested        1    0.020226
# 13        0        SC #104           0  Grazing Forested        1    0.020226
# 14        0        SC #104           0  Grazing Forested        1    0.020226
# 15        0        SC #104           0  Grazing Forested        1    0.020226
# 16        0        SC #104           0  Grazing Forested        1    0.020226
# 17        0        SC #104           0  Grazing Forested        1    0.020226
# 18        0        SC #104           0  Grazing Forested        1    0.020226
# 19        0        SC #104           0  Grazing Forested        1    0.020226
# 20        0        SC #104           0  Grazing Forested        1    0.020226
# 21        0        SC #104           0  Grazing Forested        1    0.020226
# 22        0        SC #104           0  Grazing Forested        1    0.020226
# 23        0        SC #104           0  Grazing Forested        1    0.020226
# 24        0        SC #104           0  Grazing Forested        1    0.020226
# 25        0        SC #104           0  Grazing Forested        1    0.020226
# 26        0        SC #104           0  Grazing Forested        1    0.020226
# 27        0        SC #104           0  Grazing Forested        1    0.020226
# 28        0        SC #104           0  Grazing Forested        1    0.020226
# 29        0        SC #104           0  Grazing Forested        1    0.020226
# ...     ...            ...         ...               ...      ...         ...
# 13315     0         SC #96           0      Grazing Open       85    0.020226
# 13316     0         SC #96           0      Grazing Open       85    0.020226
# 13317     0         SC #96           0      Grazing Open       85    0.020226
# 13318     0         SC #96           0      Grazing Open       85    0.020226
# 13319     0         SC #96           0      Grazing Open       85    0.020226
# 13318   54.884146  0.124948    0.00239         0.001338        1           0
# 13319   54.884146  0.124948    0.00239         0.001338        1           0
# 13320   54.884146  0.124948    0.00239         0.001338        1           0
# 13321   54.884146  0.124948    0.00239         0.001338        1           0
# 13322   54.884146  0.124948    0.00239         0.001338        1           0
# 13323   54.884146  0.124948    0.00239         0.001338        1           0
# 13324   54.884146  0.124948    0.00239         0.001338        1           0
# 13325   54.884146  0.124948    0.00239         0.001338        1           0
# 13326   54.884146  0.124948    0.00239         0.001338        1           0
# 13327   54.884146  0.124948    0.00239         0.001338        1           0
# 13328   54.884146  0.124948    0.00239         0.001338        1           0
# 13329   54.884146  0.124948    0.00239         0.001338        1           0
# 13330   54.884146  0.124948    0.00239         0.001338        1           0
# 13331   54.884146  0.124948    0.00239         0.001338        1           0
# 13332   54.884146  0.124948    0.00239         0.001338        1           0
# 13333   54.884146  0.124948    0.00239         0.001338        1           0
# 13334   54.884146  0.124948    0.00239         0.001338        1           0
# 13335   54.884146  0.124948    0.00239         0.001338        1           0
# 13336   54.884146  0.124948    0.00239         0.001338        1           0
# 13337   54.884146  0.124948    0.00239         0.001338        1           0
# 13338   54.884146  0.124948    0.00239         0.001338        1           0
# 13339   54.884146  0.124948    0.00239         0.001338        1           0
# 13340   54.884146  0.124948    0.00239         0.001338        1           0
# 13341   54.884146  0.124948    0.00239         0.001338        1           0
# 13342   54.884146  0.124948    0.00239         0.001338        1           0
# 13343   54.884146  0.124948    0.00239         0.001338        1           0
# 13344   54.884146  0.124948    0.00239         0.001338        1           0
#
#        Time_Step
# 0      1/03/1990
# 1      1/12/1979
# 2      1/03/1980
# 3      1/06/1980
# 4      1/09/1980
# 5      1/12/1980
# 6      1/03/1981
# 7      1/06/1981
# 8      1/09/1981
# 9      1/12/1981
# 10     1/03/1982
# 11     1/06/1982
# 12     1/09/1982
# 13     1/12/1982
# 14     1/03/1983
# 15     1/06/1983
# 16     1/09/1983
# 17     1/12/1983
# 18     1/03/1984
# 19     1/06/1984
# 20     1/09/1984
# 21     1/12/1984
# 22     1/03/1985
# 23     1/06/1985
# 24     1/09/1985
# 25     1/12/1985
# 26     1/03/1986
# 27     1/06/1986
# 28     1/09/1986
# 29     1/12/1986
# ...          ...
# 13315  1/09/2011
# 13316  1/12/2011
# 13317  1/03/2012
# 13318  1/06/2012
# 13319  1/09/2012
# 13320  1/12/2012
# 13321  1/03/2013
# 13322  1/06/2013
# 13323  1/09/2013
# 13324  1/12/2013
# 13325  1/03/2014
# 13326  1/06/2014
# 13327  1/09/2014
# 13328  1/12/2014
# 13329  1/03/2015
# 13330  1/06/2015
# 13331  1/09/2015
# 13332  1/12/2015
# 13333  1/03/2016
# 13334  1/06/2016
# 13335  1/09/2016
# 13336  1/12/2016
# 13337  1/03/2017
# 13338  1/06/2017
# 13339  1/09/2017
# 13340  1/12/2017
# 13341  1/03/2018
# 13342  1/06/2018
# 13343  1/09/2018
# 13344  1/12/2018
#
# [13345 rows x 13 columns]

# %%
v.shutdown()
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-19-e7fd7e673e53> in <module>
# ----> 1 v.shutdown()
#
# C:\ProgramData\Anaconda3\lib\site-packages\veneer\general.py in shutdown(self)
#      75             return
#      76         raise Exception(
# ---> 77             "Connection didn't reset. Shutdown may not have worked")
#      78
#      79     def _replace_inf(self, text):
#
# Exception: Connection didn't reset. Shutdown may not have worked
