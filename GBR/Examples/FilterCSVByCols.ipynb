# %%
# Filter CSV By Contents
import pandas as pd
#import pandasql as psql
import glob
import os


reqCols = ['Date', 'Flow m3_per_s', 'Sediment - Fine kg', 'Sediment - Coarse kg', 'N_Particulate kg', 'N_DIN kg', 'N_DON kg', 'P_Particulate kg', 'P_DOP kg', 'P_FRP kg']

basePathSource = r'\\athenasmb\pdreef\Source_Modelling\ereefs\eReefs_Extension_May2019'
basePathDest = r'\\athenasmb\pdreef\Source_Modelling\ereefs\eReefs_Extension_May2019\ConstitFiltered'

# %%
def doFiltering(inputFile, outputFile, theCols):
    
    
    df = pd.read_csv(inputFile)
    
    #filtered = df.loc[df[filterColName].isin(reqVals)]
    
    df.to_csv(outputFile, index=False, columns=theCols)

    print("Done " + inputFile)

# %%
regBit = '\\Baseline_AggregatedRegionalTimeseries\\BM_RC9_Baseline_Aggregated\\'

inFile = basePathSource + regBit + 'Baffle_Aggregated_Outflow.csv'
outFile = basePathDest + regBit + 'Baffle_Aggregated_Outflow.csv'
doFiltering(inFile, outFile, reqCols)

inFile = basePathSource + regBit + 'Burnett_Aggregated_Outflow.csv'
outFile = basePathDest + regBit + 'Burnett_Aggregated_Outflow.csv'
doFiltering(inFile, outFile, reqCols)

inFile = basePathSource + regBit + 'Burrum_Aggregated_Outflow.csv'
outFile = basePathDest + regBit + 'Burrum_Aggregated_Outflow.csv'
doFiltering(inFile, outFile, reqCols)

inFile = basePathSource + regBit + 'Kolan_Aggregated_Outflow.csv'
outFile = basePathDest + regBit + 'Kolan_Aggregated_Outflow.csv'
doFiltering(inFile, outFile, reqCols)

inFile = basePathSource + regBit + 'Mary_Aggregated_Outflow.csv'
outFile = basePathDest + regBit + 'Mary_Aggregated_Outflow.csv'
doFiltering(inFile, outFile, reqCols)

regBit = '\\Baseline_AggregatedRegionalTimeseries\\BU_RC9_Baseline_Aggregated\\'

inFile = basePathSource + regBit + 'Black_Aggregated_Outflow.csv'
outFile = basePathDest + regBit + 'Black_Aggregated_Outflow.csv'
doFiltering(inFile, outFile, reqCols)

inFile = basePathSource + regBit + 'Burdekin_Aggregated_Outflow.csv'
outFile = basePathDest + regBit + 'Burdekin_Aggregated_Outflow.csv'
doFiltering(inFile, outFile, reqCols)

inFile = basePathSource + regBit + 'Don_Aggregated_Outflow.csv'
outFile = basePathDest + regBit + 'Don_Aggregated_Outflow.csv'
doFiltering(inFile, outFile, reqCols)

inFile = basePathSource + regBit + 'Haughton_Aggregated_Outflow.csv'
outFile = basePathDest + regBit + 'Haughton_Aggregated_Outflow.csv'
doFiltering(inFile, outFile, reqCols)

inFile = basePathSource + regBit + 'Ross_Aggregated_Outflow.csv'
outFile = basePathDest + regBit + 'Ross_Aggregated_Outflow.csv'
doFiltering(inFile, outFile, reqCols)

regBit = '\\Baseline_AggregatedRegionalTimeseries\\CY_RC9_Baseline_Aggregated\\'

inFile = basePathSource + regBit + 'Endeavour River_Aggregated_Outflow.csv'
outFile = basePathDest + regBit + 'Endeavour River_Aggregated_Outflow.csv'
doFiltering(inFile, outFile, reqCols)

inFile = basePathSource + regBit + 'Jacky Jacky Creek_Aggregated_Outflow.csv'
outFile = basePathDest + regBit + 'Jacky Jacky Creek_Aggregated_Outflow.csv'
doFiltering(inFile, outFile, reqCols)

inFile = basePathSource + regBit + 'Jeannie River_Aggregated_Outflow.csv'
outFile = basePathDest + regBit + 'Jeannie River_Aggregated_Outflow.csv'
doFiltering(inFile, outFile, reqCols)

inFile = basePathSource + regBit + 'Lockhart River_Aggregated_Outflow.csv'
outFile = basePathDest + regBit + 'Lockhart River_Aggregated_Outflow.csv'
doFiltering(inFile, outFile, reqCols)

inFile = basePathSource + regBit + 'Normanby River_Aggregated_Outflow.csv'
outFile = basePathDest + regBit + 'Normanby River_Aggregated_Outflow.csv'
doFiltering(inFile, outFile, reqCols)

inFile = basePathSource + regBit + 'Olive Pascoe_Aggregated_Outflow.csv'
outFile = basePathDest + regBit + 'Olive Pascoe_Aggregated_Outflow.csv'
doFiltering(inFile, outFile, reqCols)

inFile = basePathSource + regBit + 'Stewart River_Aggregated_Outflow.csv'
outFile = basePathDest + regBit + 'Stewart River_Aggregated_Outflow.csv'
doFiltering(inFile, outFile, reqCols)

regBit = '\\Baseline_AggregatedRegionalTimeseries\\FI_RC9_Baseline_Aggregated\\'

inFile = basePathSource + regBit + 'Boyne_Aggregated_Outflow.csv'
outFile = basePathDest + regBit + 'Boyne_Aggregated_Outflow.csv'
doFiltering(inFile, outFile, reqCols)

inFile = basePathSource + regBit + 'Calliope_Aggregated_Outflow.csv'
outFile = basePathDest + regBit + 'Calliope_Aggregated_Outflow.csv'
doFiltering(inFile, outFile, reqCols)

inFile = basePathSource + regBit + 'Fitzroy_Aggregated_Outflow.csv'
outFile = basePathDest + regBit + 'Fitzroy_Aggregated_Outflow.csv'
doFiltering(inFile, outFile, reqCols)

inFile = basePathSource + regBit + 'Shoalwater_Aggregated_Outflow.csv'
outFile = basePathDest + regBit + 'Shoalwater_Aggregated_Outflow.csv'
doFiltering(inFile, outFile, reqCols)

inFile = basePathSource + regBit + 'Styx_Aggregated_Outflow.csv'
outFile = basePathDest + regBit + 'Styx_Aggregated_Outflow.csv'
doFiltering(inFile, outFile, reqCols)

inFile = basePathSource + regBit + 'Water Park_Aggregated_Outflow.csv'
outFile = basePathDest + regBit + 'Water Park_Aggregated_Outflow.csv'
doFiltering(inFile, outFile, reqCols)

regBit = '\\Baseline_AggregatedRegionalTimeseries\\MW_RC9_Baseline_Aggregated\\'

inFile = basePathSource + regBit + 'OConnel_Aggregated_Outflow.csv'
outFile = basePathDest + regBit + 'OConnel_Aggregated_Outflow.csv'
doFiltering(inFile, outFile, reqCols)

inFile = basePathSource + regBit + 'Pioneer_Aggregated_Outflow.csv'
outFile = basePathDest + regBit + 'Pioneer_Aggregated_Outflow.csv'
doFiltering(inFile, outFile, reqCols)

inFile = basePathSource + regBit + 'PlaneC_Aggregated_Outflow.csv'
outFile = basePathDest + regBit + 'PlaneC_Aggregated_Outflow.csv'
doFiltering(inFile, outFile, reqCols)

inFile = basePathSource + regBit + 'Prossie_Aggregated_Outflow.csv'
outFile = basePathDest + regBit + 'Prossie_Aggregated_Outflow.csv'
doFiltering(inFile, outFile, reqCols)

regBit = '\\Baseline_AggregatedRegionalTimeseries\\WT_RC9_Baseline_Aggregated\\'

inFile = basePathSource + regBit + 'Barron_Aggregated_Outflow.csv'
outFile = basePathDest + regBit + 'Barron_Aggregated_Outflow.csv'
doFiltering(inFile, outFile, reqCols)

inFile = basePathSource + regBit + 'Daintree_Aggregated_Outflow.csv'
outFile = basePathDest + regBit + 'Daintree_Aggregated_Outflow.csv'
doFiltering(inFile, outFile, reqCols)

inFile = basePathSource + regBit + 'Herbert_Aggregated_Outflow.csv'
outFile = basePathDest + regBit + 'Herbert_Aggregated_Outflow.csv'
doFiltering(inFile, outFile, reqCols)

inFile = basePathSource + regBit + 'Johnstone_Aggregated_Outflow.csv'
outFile = basePathDest + regBit + 'Johnstone_Aggregated_Outflow.csv'
doFiltering(inFile, outFile, reqCols)

inFile = basePathSource + regBit + 'Mossman_Aggregated_Outflow.csv'
outFile = basePathDest + regBit + 'Mossman_Aggregated_Outflow.csv'
doFiltering(inFile, outFile, reqCols)

inFile = basePathSource + regBit + 'Mulgrave-Russell_Aggregated_Outflow.csv'
outFile = basePathDest + regBit + 'Mulgrave-Russell_Aggregated_Outflow.csv'
doFiltering(inFile, outFile, reqCols)

inFile = basePathSource + regBit + 'Murray_Aggregated_Outflow.csv'
outFile = basePathDest + regBit + 'Murray_Aggregated_Outflow.csv'
doFiltering(inFile, outFile, reqCols)

inFile = basePathSource + regBit + 'Tully_Aggregated_Outflow.csv'
outFile = basePathDest + regBit + 'Tully_Aggregated_Outflow.csv'
doFiltering(inFile, outFile, reqCols)


print("All Baseline Done")
# Out:
# Done \\athenasmb\pdreef\Source_Modelling\ereefs\eReefs_Extension_May2019\Baseline_AggregatedRegionalTimeseries\BM_RC9_Baseline_Aggregated\Baffle_Aggregated_Outflow.csv
# Done \\athenasmb\pdreef\Source_Modelling\ereefs\eReefs_Extension_May2019\Baseline_AggregatedRegionalTimeseries\BM_RC9_Baseline_Aggregated\Burnett_Aggregated_Outflow.csv
# Done \\athenasmb\pdreef\Source_Modelling\ereefs\eReefs_Extension_May2019\Baseline_AggregatedRegionalTimeseries\BM_RC9_Baseline_Aggregated\Burrum_Aggregated_Outflow.csv
# Done \\athenasmb\pdreef\Source_Modelling\ereefs\eReefs_Extension_May2019\Baseline_AggregatedRegionalTimeseries\BM_RC9_Baseline_Aggregated\Kolan_Aggregated_Outflow.csv
# Done \\athenasmb\pdreef\Source_Modelling\ereefs\eReefs_Extension_May2019\Baseline_AggregatedRegionalTimeseries\BM_RC9_Baseline_Aggregated\Mary_Aggregated_Outflow.csv
# ...

# %%
regBit = '\\Predev_AggregatedRegionalTimeseries\\BM_RC9_Predev_Aggregated\\'

inFile = basePathSource + regBit + 'Baffle_Aggregated_Outflow.csv'
outFile = basePathDest + regBit + 'Baffle_Aggregated_Outflow.csv'
doFiltering(inFile, outFile, reqCols)

inFile = basePathSource + regBit + 'Burnett_Aggregated_Outflow.csv'
outFile = basePathDest + regBit + 'Burnett_Aggregated_Outflow.csv'
doFiltering(inFile, outFile, reqCols)

inFile = basePathSource + regBit + 'Burrum_Aggregated_Outflow.csv'
outFile = basePathDest + regBit + 'Burrum_Aggregated_Outflow.csv'
doFiltering(inFile, outFile, reqCols)

inFile = basePathSource + regBit + 'Kolan_Aggregated_Outflow.csv'
outFile = basePathDest + regBit + 'Kolan_Aggregated_Outflow.csv'
doFiltering(inFile, outFile, reqCols)

inFile = basePathSource + regBit + 'Mary_Aggregated_Outflow.csv'
outFile = basePathDest + regBit + 'Mary_Aggregated_Outflow.csv'
doFiltering(inFile, outFile, reqCols)

regBit = '\\Predev_AggregatedRegionalTimeseries\\BU_RC9_Predev_Aggregated\\'

inFile = basePathSource + regBit + 'Black_Aggregated_Outflow.csv'
outFile = basePathDest + regBit + 'Black_Aggregated_Outflow.csv'
doFiltering(inFile, outFile, reqCols)

inFile = basePathSource + regBit + 'Burdekin_Aggregated_Outflow.csv'
outFile = basePathDest + regBit + 'Burdekin_Aggregated_Outflow.csv'
doFiltering(inFile, outFile, reqCols)

inFile = basePathSource + regBit + 'Don_Aggregated_Outflow.csv'
outFile = basePathDest + regBit + 'Don_Aggregated_Outflow.csv'
doFiltering(inFile, outFile, reqCols)

inFile = basePathSource + regBit + 'Haughton_Aggregated_Outflow.csv'
outFile = basePathDest + regBit + 'Haughton_Aggregated_Outflow.csv'
doFiltering(inFile, outFile, reqCols)

inFile = basePathSource + regBit + 'Ross_Aggregated_Outflow.csv'
outFile = basePathDest + regBit + 'Ross_Aggregated_Outflow.csv'
doFiltering(inFile, outFile, reqCols)

regBit = '\\Predev_AggregatedRegionalTimeseries\\CY_RC9_Predev_Aggregated\\'

inFile = basePathSource + regBit + 'Endeavour River_Aggregated_Outflow.csv'
outFile = basePathDest + regBit + 'Endeavour River_Aggregated_Outflow.csv'
doFiltering(inFile, outFile, reqCols)

inFile = basePathSource + regBit + 'Jacky Jacky Creek_Aggregated_Outflow.csv'
outFile = basePathDest + regBit + 'Jacky Jacky Creek_Aggregated_Outflow.csv'
doFiltering(inFile, outFile, reqCols)

inFile = basePathSource + regBit + 'Jeannie River_Aggregated_Outflow.csv'
outFile = basePathDest + regBit + 'Jeannie River_Aggregated_Outflow.csv'
doFiltering(inFile, outFile, reqCols)

inFile = basePathSource + regBit + 'Lockhart River_Aggregated_Outflow.csv'
outFile = basePathDest + regBit + 'Lockhart River_Aggregated_Outflow.csv'
doFiltering(inFile, outFile, reqCols)

inFile = basePathSource + regBit + 'Normanby River_Aggregated_Outflow.csv'
outFile = basePathDest + regBit + 'Normanby River_Aggregated_Outflow.csv'
doFiltering(inFile, outFile, reqCols)

inFile = basePathSource + regBit + 'Olive Pascoe_Aggregated_Outflow.csv'
outFile = basePathDest + regBit + 'Olive Pascoe_Aggregated_Outflow.csv'
doFiltering(inFile, outFile, reqCols)

inFile = basePathSource + regBit + 'Stewart River_Aggregated_Outflow.csv'
outFile = basePathDest + regBit + 'Stewart River_Aggregated_Outflow.csv'
doFiltering(inFile, outFile, reqCols)

regBit = '\\Predev_AggregatedRegionalTimeseries\\FI_RC9_Predev_Aggregated\\'

inFile = basePathSource + regBit + 'Boyne_Aggregated_Outflow.csv'
outFile = basePathDest + regBit + 'Boyne_Aggregated_Outflow.csv'
doFiltering(inFile, outFile, reqCols)

inFile = basePathSource + regBit + 'Calliope_Aggregated_Outflow.csv'
outFile = basePathDest + regBit + 'Calliope_Aggregated_Outflow.csv'
doFiltering(inFile, outFile, reqCols)

inFile = basePathSource + regBit + 'Fitzroy_Aggregated_Outflow.csv'
outFile = basePathDest + regBit + 'Fitzroy_Aggregated_Outflow.csv'
doFiltering(inFile, outFile, reqCols)

inFile = basePathSource + regBit + 'Shoalwater_Aggregated_Outflow.csv'
outFile = basePathDest + regBit + 'Shoalwater_Aggregated_Outflow.csv'
doFiltering(inFile, outFile, reqCols)

inFile = basePathSource + regBit + 'Styx_Aggregated_Outflow.csv'
outFile = basePathDest + regBit + 'Styx_Aggregated_Outflow.csv'
doFiltering(inFile, outFile, reqCols)

inFile = basePathSource + regBit + 'Water Park_Aggregated_Outflow.csv'
outFile = basePathDest + regBit + 'Water Park_Aggregated_Outflow.csv'
doFiltering(inFile, outFile, reqCols)

regBit = '\\Predev_AggregatedRegionalTimeseries\\MW_RC9_Predev_Aggregated\\'

inFile = basePathSource + regBit + 'OConnel_Aggregated_Outflow.csv'
outFile = basePathDest + regBit + 'OConnel_Aggregated_Outflow.csv'
doFiltering(inFile, outFile, reqCols)

inFile = basePathSource + regBit + 'Pioneer_Aggregated_Outflow.csv'
outFile = basePathDest + regBit + 'Pioneer_Aggregated_Outflow.csv'
doFiltering(inFile, outFile, reqCols)

inFile = basePathSource + regBit + 'PlaneC_Aggregated_Outflow.csv'
outFile = basePathDest + regBit + 'PlaneC_Aggregated_Outflow.csv'
doFiltering(inFile, outFile, reqCols)

inFile = basePathSource + regBit + 'Prossie_Aggregated_Outflow.csv'
outFile = basePathDest + regBit + 'Prossie_Aggregated_Outflow.csv'
doFiltering(inFile, outFile, reqCols)

regBit = '\\Predev_AggregatedRegionalTimeseries\\WT_RC9_Predev_Aggregated\\'

inFile = basePathSource + regBit + 'Barron_Aggregated_Outflow.csv'
outFile = basePathDest + regBit + 'Barron_Aggregated_Outflow.csv'
doFiltering(inFile, outFile, reqCols)

inFile = basePathSource + regBit + 'Daintree_Aggregated_Outflow.csv'
outFile = basePathDest + regBit + 'Daintree_Aggregated_Outflow.csv'
doFiltering(inFile, outFile, reqCols)

inFile = basePathSource + regBit + 'Herbert_Aggregated_Outflow.csv'
outFile = basePathDest + regBit + 'Herbert_Aggregated_Outflow.csv'
doFiltering(inFile, outFile, reqCols)

inFile = basePathSource + regBit + 'Johnstone_Aggregated_Outflow.csv'
outFile = basePathDest + regBit + 'Johnstone_Aggregated_Outflow.csv'
doFiltering(inFile, outFile, reqCols)

inFile = basePathSource + regBit + 'Mossman_Aggregated_Outflow.csv'
outFile = basePathDest + regBit + 'Mossman_Aggregated_Outflow.csv'
doFiltering(inFile, outFile, reqCols)

inFile = basePathSource + regBit + 'Mulgrave-Russell_Aggregated_Outflow.csv'
outFile = basePathDest + regBit + 'Mulgrave-Russell_Aggregated_Outflow.csv'
doFiltering(inFile, outFile, reqCols)

inFile = basePathSource + regBit + 'Murray_Aggregated_Outflow.csv'
outFile = basePathDest + regBit + 'Murray_Aggregated_Outflow.csv'
doFiltering(inFile, outFile, reqCols)

inFile = basePathSource + regBit + 'Tully_Aggregated_Outflow.csv'
outFile = basePathDest + regBit + 'Tully_Aggregated_Outflow.csv'
doFiltering(inFile, outFile, reqCols)


print("All Predev Done")
# Out:
# Done \\athenasmb\pdreef\Source_Modelling\ereefs\eReefs_Extension_May2019\Predev_AggregatedRegionalTimeseries\BM_RC9_Predev_Aggregated\Baffle_Aggregated_Outflow.csv
# Done \\athenasmb\pdreef\Source_Modelling\ereefs\eReefs_Extension_May2019\Predev_AggregatedRegionalTimeseries\BM_RC9_Predev_Aggregated\Burnett_Aggregated_Outflow.csv
# Done \\athenasmb\pdreef\Source_Modelling\ereefs\eReefs_Extension_May2019\Predev_AggregatedRegionalTimeseries\BM_RC9_Predev_Aggregated\Burrum_Aggregated_Outflow.csv
# Done \\athenasmb\pdreef\Source_Modelling\ereefs\eReefs_Extension_May2019\Predev_AggregatedRegionalTimeseries\BM_RC9_Predev_Aggregated\Kolan_Aggregated_Outflow.csv
# Done \\athenasmb\pdreef\Source_Modelling\ereefs\eReefs_Extension_May2019\Predev_AggregatedRegionalTimeseries\BM_RC9_Predev_Aggregated\Mary_Aggregated_Outflow.csv
# Done \\athenasmb\pdreef\Source_Modelling\ereefs\eReefs_Extension_May2019\Predev_AggregatedRegionalTimeseries\BU_RC9_Predev_Aggregated\Black_Aggregated_Outflow.csv
# ...
