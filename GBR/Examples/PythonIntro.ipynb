# %% [markdown]
# # Python Introduction
#
# The Python language (and the Jupyter/IPython notebook system) is a great environment for data analysis and scientific computing
#
# Its made up of cells.
#
# Cells have a type:
# * **Code cells** - You can enter Python commands and run to get a result
# * **Markdown** - Good for documentation
# * other stuff...
#
# Code cells have results... Select the cell and push Shift-Enter to run (or click the play button on the toolbar)

# %%
5 + 7
# Out:
# 12

# %%
2**4
# Out:
# 16

# %% [markdown]
# Commands starting with % are called Magic Commands in IPython...
#
# They are useful for changing the way to system works. For example, enabling inline charting (channelling the Matlab history)
#
# %pylab inline

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# Some very powerful number crunching tools are available in numpy (aka np)

# %%
xs = np.random.normal(size=100000)

# %%
ys = xs + np.random.normal(size=100000)

# %%
scatter(xs,ys)
