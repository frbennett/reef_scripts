# %%
# Some steps required until these Python modules are properly installed...
import sys
sys.path.append('../Modules')
sys.path.append('../../../../veneer-py')
# Get the Source scripting components (veneer) and GBR specific stuff
import veneer
import gbr
# %pylab inline
import pandas as pd
import os
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
constituents = ['Sediment - Fine','N_DIN','N_Particulate','P_Particulate']
site = 'GS133003A'
path = 'D:/Fitzroy/Results/Fitzroy Rebuild 2014/Baseline_3818_OrigParams/TimeSeries'

# %%
        def _fn(con):
            return os.path.join(path,con,"%s_%s_kilograms.csv"%(con,site))
        def _read(con):
            return pd.read_csv(_fn(con),index_col=0,parse_dates=True,dayfirst=True,names = ['Date', con])

# %%
pd.DataFrame([_read(c)[c] for c in constituents]).transpose()
# Out:
#             Sediment - Fine      N_DIN  N_Particulate  P_Particulate
# Date
# 1986-07-01         0.000000   0.000000       0.000000       0.000000
# 1986-07-02         0.000000   0.000000       0.000000       0.000000
# 1986-07-03         0.000000   0.000000       0.000000       0.000000
# 1986-07-04         0.000000   0.000000       0.000000       0.000000
# 1986-07-05        17.441683   0.199479       0.005789       0.004606
# 1986-07-06        14.312222   0.163037       0.004770       0.003791
# 1986-07-07        11.872854   0.134779       0.003971       0.003154
# 1986-07-08         9.946298   0.112564       0.003337       0.002648
# 1986-07-09         8.406593   0.094880       0.002828       0.002243
# 1986-07-10         7.162814   0.080647       0.002416       0.001915
# 1986-07-11         6.147983   0.069071       0.002078       0.001646
# 1986-07-12         5.312566   0.059569       0.001799       0.001425
# ...

# %%
obs = _

# %%
obs.to_csv('D:/Fitzroy/Obs/observed_loads_'+site+'_kg.csv')

# %%
x = "%s%s_%s%s"

# %%
x.count('%s')//2
# Out:
# 2

# %%
x%([1,2]*2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-31-dc1b9e1922b0> in <module>()
# ----> 1 x%([1,2]*2)
#
# TypeError: not enough arguments for format string

# %%
y = [1,2]*1

# %%
y
# Out:
# [1, 2]

# %%
x%y
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-28-8d559ddff3cf> in <module>()
# ----> 1 x%y
#
# TypeError: not enough arguments for format string

# %%
x
# Out:
# '%s%s_%s%s'

# %%
pd.Panel?
