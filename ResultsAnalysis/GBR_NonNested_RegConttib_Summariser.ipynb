# %%
### This will be the routine used to take a non-nested GBR regional contributor table and produce the summaries
### that we typically supply
### will eventually try to declare as much stuff up front as possible

import pandas as pd
import numpy as np

selectedConstituents = ['Sediment - Fine', 'N_Particulate']
rawcontrib = pd.read_csv('P:\projects\RC7_Results\FZ_Baseline_RegContributorDataGrid_Rob.csv')

rawcontrib['AnnLoadToStreamKG'] = rawcontrib['LoadToStream (kg)'].div(rawcontrib['Num_Days']).mul(365.25)
rawcontrib['AnnLoadToExportKG'] = rawcontrib['LoadToRegExport (kg)'].div(rawcontrib['Num_Days']).mul(365.25)
rawcontrib['AreaHA'] = rawcontrib['AreaM2'].div(10000)

### Could put alternatives in here to load a different regoinalisation from CSV

# %%
rawcontrib.head(20)
# Out:
#        Rep_Region ModelElement Constituent     FU  AreaM2  \
# 0   Fitzroy River     SC #1608    Atrazine  Water     0.0
# 1   Fitzroy River     SC #1608    Atrazine  Water     0.0
# 2   Fitzroy River     SC #1608    Atrazine  Water     0.0
# 3   Fitzroy River     SC #1608    Atrazine  Water     0.0
# 4   Fitzroy River     SC #1608    Atrazine  Water     0.0
# 5   Fitzroy River     SC #1608    Atrazine  Water     0.0
# 6   Fitzroy River     SC #1608    Atrazine  Water     0.0
# 7   Fitzroy River     SC #1608    Atrazine  Water     0.0
# 8   Fitzroy River     SC #1608    Atrazine  Water     0.0
# 9   Fitzroy River     SC #1608    Atrazine  Water     0.0
# 10  Fitzroy River     SC #1608      Diuron  Water     0.0
# 11  Fitzroy River     SC #1608      Diuron  Water     0.0
# 12  Fitzroy River     SC #1608      Diuron  Water     0.0
# 13  Fitzroy River     SC #1608      Diuron  Water     0.0
# 14  Fitzroy River     SC #1608      Diuron  Water     0.0
# 15  Fitzroy River     SC #1608      Diuron  Water     0.0
# 16  Fitzroy River     SC #1608      Diuron  Water     0.0
# 17  Fitzroy River     SC #1608      Diuron  Water     0.0
# 18  Fitzroy River     SC #1608      Diuron  Water     0.0
# 19  Fitzroy River     SC #1608      Diuron  Water     0.0
#
#                             Process  LoadToStream (kg)  LoadToRegExport (kg)  \
# 0                         Undefined                0.0                   0.0
# 1            Hillslope surface soil                0.0                   0.0
# 2        Hillslope sub-surface soil                0.0                   0.0
# 3                             Gully                0.0                   0.0
# 4   Hillslope no source distinction                0.0                   0.0
# 5                 Diffuse Dissolved                0.0                   0.0
# 6                           Seepage                0.0                   0.0
# 7                        Streambank                0.0                   0.0
# 8            Channel Remobilisation                0.0                   0.0
# 9                      Point Source                0.0                   0.0
# 10                        Undefined                0.0                   0.0
# 11           Hillslope surface soil                0.0                   0.0
# 12       Hillslope sub-surface soil                0.0                   0.0
# 13                            Gully                0.0                   0.0
# 14  Hillslope no source distinction                0.0                   0.0
# 15                Diffuse Dissolved                0.0                   0.0
# 16                          Seepage                0.0                   0.0
# 17                       Streambank                0.0                   0.0
# 18           Channel Remobilisation                0.0                   0.0
# 19                     Point Source                0.0                   0.0
#
#         RSDR  Num_Days  AnnLoadToStreamKG  AnnLoadToExportKG  AreaHA
# 0   0.605067     10227                0.0                0.0     0.0
# 1   0.605067     10227                0.0                0.0     0.0
# 2   0.605067     10227                0.0                0.0     0.0
# 3   0.605067     10227                0.0                0.0     0.0
# 4   0.605067     10227                0.0                0.0     0.0
# 5   0.605067     10227                0.0                0.0     0.0
# 6   0.605067     10227                0.0                0.0     0.0
# 7   0.605067     10227                0.0                0.0     0.0
# 8   0.605067     10227                0.0                0.0     0.0
# 9   0.605067     10227                0.0                0.0     0.0
# 10  0.000000     10227                0.0                0.0     0.0
# 11  0.000000     10227                0.0                0.0     0.0
# 12  0.000000     10227                0.0                0.0     0.0
# 13  0.000000     10227                0.0                0.0     0.0
# 14  0.000000     10227                0.0                0.0     0.0
# 15  0.000000     10227                0.0                0.0     0.0
# 16  0.000000     10227                0.0                0.0     0.0
# 17  0.000000     10227                0.0                0.0     0.0
# 18  0.000000     10227                0.0                0.0     0.0
# 19  0.000000     10227                0.0                0.0     0.0

# %%
### Can keep reporting region in the area table, as this is our Non-Nested notebook
catchFuArea = pd.DataFrame(rawcontrib.groupby(['Rep_Region','ModelElement','FU']).agg({'AreaHA':'first'})).reset_index()

# %%
catchFuArea.head(15)
# Out:
#      Rep_Region ModelElement                  FU       AreaHA
# 0   Boyne River     SC #1802        Conservation   180.458801
# 1   Boyne River     SC #1802    Dryland Cropping     0.000000
# 2   Boyne River     SC #1802            Forestry     1.168799
# 3   Boyne River     SC #1802    Grazing Forested  5187.780448
# 4   Boyne River     SC #1802        Grazing Open  2632.294710
# 5   Boyne River     SC #1802        Horticulture    11.278095
# 6   Boyne River     SC #1802  Irrigated Cropping     0.000000
# 7   Boyne River     SC #1802               Other   451.709822
# 8   Boyne River     SC #1802              Stream     0.000000
# 9   Boyne River     SC #1802           Sugarcane     0.000000
# 10  Boyne River     SC #1802               Urban   779.616216
# 11  Boyne River     SC #1802               Water   272.113110
# 12  Boyne River     SC #1803        Conservation  2591.907044
# 13  Boyne River     SC #1803    Dryland Cropping     0.000000
# 14  Boyne River     SC #1803            Forestry   407.412903

# %%
regFuArea = pd.DataFrame(catchFuArea.groupby(['Rep_Region','FU']).agg({'AreaHA':'sum'})).reset_index()
regFuArea.head(25)
# Out:
#         Rep_Region                  FU         AreaHA
# 0      Boyne River        Conservation   38834.246839
# 1      Boyne River    Dryland Cropping       0.000000
# 2      Boyne River            Forestry   13358.407188
# 3      Boyne River    Grazing Forested  137831.859877
# 4      Boyne River        Grazing Open   46697.347003
# 5      Boyne River        Horticulture      75.933414
# 6      Boyne River  Irrigated Cropping     276.107147
# 7      Boyne River               Other    3357.835763
# 8      Boyne River              Stream       0.000000
# 9      Boyne River           Sugarcane       0.000000
# 10     Boyne River               Urban    1667.535850
# 11     Boyne River               Water    7649.196919
# 12  Calliope River        Conservation   13239.165751
# 13  Calliope River    Dryland Cropping      16.120796
# 14  Calliope River            Forestry   13249.351166
# 15  Calliope River    Grazing Forested   89388.558780
# 16  Calliope River        Grazing Open  101088.297488
# 17  Calliope River        Horticulture     279.959497
# 18  Calliope River  Irrigated Cropping      33.261786
# 19  Calliope River               Other    3606.611691
# 20  Calliope River              Stream       0.000000
# 21  Calliope River           Sugarcane       0.000000
# 22  Calliope River               Urban    4271.340957
# 23  Calliope River               Water   16338.462088
# 24   Curtis Island        Conservation   14759.982239

# %%
#regLuseSummary = pd.DataFrame(rawcontrib.groupby(['Rep_Region','Constituent','FU','Process']).agg({'AnnLoadToStreamKG':'sum','AnnLoadToExportKG':'sum'})).reset_index()
regLuseSummary = pd.DataFrame(rawcontrib[rawcontrib['Constituent'].isin(selectedConstituents)].groupby(['Rep_Region','Constituent','FU','Process']).agg({'AnnLoadToStreamKG':'sum','AnnLoadToExportKG':'sum'})).reset_index()
regLuseSummary.head(15)
# Out:
#      Rep_Region    Constituent                FU  \
# 0   Boyne River  N_Particulate      Conservation
# 1   Boyne River  N_Particulate      Conservation
# 2   Boyne River  N_Particulate      Conservation
# 3   Boyne River  N_Particulate      Conservation
# 4   Boyne River  N_Particulate      Conservation
# 5   Boyne River  N_Particulate      Conservation
# 6   Boyne River  N_Particulate      Conservation
# 7   Boyne River  N_Particulate      Conservation
# 8   Boyne River  N_Particulate      Conservation
# 9   Boyne River  N_Particulate      Conservation
# 10  Boyne River  N_Particulate  Dryland Cropping
# 11  Boyne River  N_Particulate  Dryland Cropping
# 12  Boyne River  N_Particulate  Dryland Cropping
# 13  Boyne River  N_Particulate  Dryland Cropping
# 14  Boyne River  N_Particulate  Dryland Cropping
#
#                             Process  AnnLoadToStreamKG  AnnLoadToExportKG
# 0            Channel Remobilisation           0.000000           0.000000
# 1                 Diffuse Dissolved           0.000000           0.000000
# 2                             Gully          53.445715          19.451487
# 3   Hillslope no source distinction      283583.774535       31570.471397
# 4        Hillslope sub-surface soil           0.000000           0.000000
# 5            Hillslope surface soil           0.000000           0.000000
# 6                      Point Source           0.000000           0.000000
# 7                           Seepage           0.000000           0.000000
# 8                        Streambank           0.000000           0.000000
# 9                         Undefined           0.000000           0.000000
# 10           Channel Remobilisation           0.000000           0.000000
# 11                Diffuse Dissolved           0.000000           0.000000
# 12                            Gully           0.000000           0.000000
# 13  Hillslope no source distinction           0.000000           0.000000
# 14       Hillslope sub-surface soil           0.000000           0.000000

# %%
### Join/merge with Regional Areas
regLuseSumPlusArea = pd.merge(regLuseSummary, regFuArea, how='left', left_on=['Rep_Region','FU'], right_on = ['Rep_Region','FU'])
regLuseSumPlusArea.head(15)
# Out:
#      Rep_Region    Constituent                FU  \
# 0   Boyne River  N_Particulate      Conservation
# 1   Boyne River  N_Particulate      Conservation
# 2   Boyne River  N_Particulate      Conservation
# 3   Boyne River  N_Particulate      Conservation
# 4   Boyne River  N_Particulate      Conservation
# 5   Boyne River  N_Particulate      Conservation
# 6   Boyne River  N_Particulate      Conservation
# 7   Boyne River  N_Particulate      Conservation
# 8   Boyne River  N_Particulate      Conservation
# 9   Boyne River  N_Particulate      Conservation
# 10  Boyne River  N_Particulate  Dryland Cropping
# 11  Boyne River  N_Particulate  Dryland Cropping
# 12  Boyne River  N_Particulate  Dryland Cropping
# 13  Boyne River  N_Particulate  Dryland Cropping
# 14  Boyne River  N_Particulate  Dryland Cropping
#
#                             Process  AnnLoadToStreamKG  AnnLoadToExportKG  \
# 0            Channel Remobilisation           0.000000           0.000000
# 1                 Diffuse Dissolved           0.000000           0.000000
# 2                             Gully          53.445715          19.451487
# 3   Hillslope no source distinction      283583.774535       31570.471397
# 4        Hillslope sub-surface soil           0.000000           0.000000
# 5            Hillslope surface soil           0.000000           0.000000
# 6                      Point Source           0.000000           0.000000
# 7                           Seepage           0.000000           0.000000
# 8                        Streambank           0.000000           0.000000
# 9                         Undefined           0.000000           0.000000
# 10           Channel Remobilisation           0.000000           0.000000
# 11                Diffuse Dissolved           0.000000           0.000000
# 12                            Gully           0.000000           0.000000
# 13  Hillslope no source distinction           0.000000           0.000000
# 14       Hillslope sub-surface soil           0.000000           0.000000
#
#           AreaHA
# 0   38834.246839
# 1   38834.246839
# 2   38834.246839
# 3   38834.246839
# 4   38834.246839
# 5   38834.246839
# 6   38834.246839
# 7   38834.246839
# 8   38834.246839
# 9   38834.246839
# 10      0.000000
# 11      0.000000
# 12      0.000000
# 13      0.000000
# 14      0.000000

# %%
regLuseSumPlusArea.to_csv('D:/test_out.csv', index=False)
