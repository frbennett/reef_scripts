# %%
### This will be the routine used to take a non-nested GBR regional contributor table and produce the summaries
### that we typically supply
### will eventually try to declare as much stuff up front as possible

import pandas as pd
import numpy as np

selectedConstituents = ['Sediment - Fine', 'N_Particulate']
#rawcontrib = pd.read_csv('P:\projects\RC7_Results\FZ_Baseline_RegContributorDataGrid_Rob.csv')
rawcontrib = pd.read_csv('P:\projects\RC8_ResultsSets\BU\RobsRuns\BU_RC8_BL_RegContributorDataGrid_AusGovSource_P2RReg.csv')

rawcontrib['AnnLoadToStreamKG'] = rawcontrib['LoadToStream (kg)'].div(rawcontrib['Num_Days']).mul(365.25)
rawcontrib['AnnLoadToExportKG'] = rawcontrib['LoadToRegExport (kg)'].div(rawcontrib['Num_Days']).mul(365.25)
rawcontrib['AreaHA'] = rawcontrib['AreaM2'].div(10000)

### Could put alternatives in here to load a different regoinalisation from CSV

# %%
rawcontrib.head(20)
# Out:
#    Rep_Region ModelElement Constituent     FU       AreaM2  \
# 0    Burdekin     SC #1608    Atrazine  Water  4386667.446
# 1    Burdekin     SC #1608    Atrazine  Water  4386667.446
# 2    Burdekin     SC #1608    Atrazine  Water  4386667.446
# 3    Burdekin     SC #1608    Atrazine  Water  4386667.446
# 4    Burdekin     SC #1608    Atrazine  Water  4386667.446
# 5    Burdekin     SC #1608    Atrazine  Water  4386667.446
# 6    Burdekin     SC #1608    Atrazine  Water  4386667.446
# 7    Burdekin     SC #1608      Diuron  Water  4386667.446
# 8    Burdekin     SC #1608      Diuron  Water  4386667.446
# 9    Burdekin     SC #1608      Diuron  Water  4386667.446
# 10   Burdekin     SC #1608      Diuron  Water  4386667.446
# 11   Burdekin     SC #1608      Diuron  Water  4386667.446
# 12   Burdekin     SC #1608      Diuron  Water  4386667.446
# 13   Burdekin     SC #1608      Diuron  Water  4386667.446
# 14   Burdekin     SC #1608  Metribuzin  Water  4386667.446
# 15   Burdekin     SC #1608  Metribuzin  Water  4386667.446
# 16   Burdekin     SC #1608  Metribuzin  Water  4386667.446
# 17   Burdekin     SC #1608  Metribuzin  Water  4386667.446
# 18   Burdekin     SC #1608  Metribuzin  Water  4386667.446
# 19   Burdekin     SC #1608  Metribuzin  Water  4386667.446
#
#                             Process  LoadToStream (kg)  LoadToRegExport (kg)  \
# 0                         Undefined                0.0                   0.0
# 1            Hillslope surface soil                0.0                   0.0
# 2        Hillslope sub-surface soil                0.0                   0.0
# 3                             Gully                0.0                   0.0
# 4   Hillslope no source distinction                0.0                   0.0
# 5                 Diffuse Dissolved                0.0                   0.0
# 6                           Seepage                0.0                   0.0
# 7                         Undefined                0.0                   0.0
# 8            Hillslope surface soil                0.0                   0.0
# 9        Hillslope sub-surface soil                0.0                   0.0
# 10                            Gully                0.0                   0.0
# 11  Hillslope no source distinction                0.0                   0.0
# 12                Diffuse Dissolved                0.0                   0.0
# 13                          Seepage                0.0                   0.0
# 14                        Undefined                0.0                   0.0
# 15           Hillslope surface soil                0.0                   0.0
# 16       Hillslope sub-surface soil                0.0                   0.0
# 17                            Gully                0.0                   0.0
# 18  Hillslope no source distinction                0.0                   0.0
# 19                Diffuse Dissolved                0.0                   0.0
#
#     RSDR  Num_Days  AnnLoadToStreamKG  AnnLoadToExportKG      AreaHA
# 0    0.0     10227                0.0                0.0  438.666745
# 1    0.0     10227                0.0                0.0  438.666745
# 2    0.0     10227                0.0                0.0  438.666745
# 3    0.0     10227                0.0                0.0  438.666745
# 4    0.0     10227                0.0                0.0  438.666745
# 5    0.0     10227                0.0                0.0  438.666745
# 6    0.0     10227                0.0                0.0  438.666745
# 7    0.0     10227                0.0                0.0  438.666745
# 8    0.0     10227                0.0                0.0  438.666745
# 9    0.0     10227                0.0                0.0  438.666745
# 10   0.0     10227                0.0                0.0  438.666745
# 11   0.0     10227                0.0                0.0  438.666745
# 12   0.0     10227                0.0                0.0  438.666745
# 13   0.0     10227                0.0                0.0  438.666745
# 14   0.0     10227                0.0                0.0  438.666745
# 15   0.0     10227                0.0                0.0  438.666745
# 16   0.0     10227                0.0                0.0  438.666745
# 17   0.0     10227                0.0                0.0  438.666745
# 18   0.0     10227                0.0                0.0  438.666745
# 19   0.0     10227                0.0                0.0  438.666745

# %%
### Can keep reporting region in the area table, as this is our Non-Nested notebook
catchFuArea = pd.DataFrame(rawcontrib.groupby(['Rep_Region','ModelElement','FU']).agg({'AreaHA':'first'})).reset_index()

# %%
catchFuArea.head(15)
# Out:
#    Rep_Region ModelElement                  FU       AreaHA
# 0       Black        SC #2        Conservation  9507.932752
# 1       Black        SC #2    Dryland Cropping     2.384634
# 2       Black        SC #2            Forestry     0.567020
# 3       Black        SC #2    Grazing Forested   561.444247
# 4       Black        SC #2        Grazing Open   138.321154
# 5       Black        SC #2        Horticulture   172.352452
# 6       Black        SC #2  Irrigated Cropping     0.000000
# 7       Black        SC #2               Other     6.625432
# 8       Black        SC #2              Stream     0.000000
# 9       Black        SC #2           Sugarcane   138.481278
# 10      Black        SC #2       System Supply     0.000000
# 11      Black        SC #2               Urban    34.720181
# 12      Black        SC #2               Water   106.133030
# 13      Black        SC #3        Conservation  5720.146405
# 14      Black        SC #3    Dryland Cropping     0.000000

# %%
regFuArea = pd.DataFrame(catchFuArea.groupby(['Rep_Region','FU']).agg({'AreaHA':'sum'})).reset_index()
regFuArea.head(25)
# Out:
#    Rep_Region                  FU        AreaHA
# 0       Black        Conservation  4.062862e+04
# 1       Black    Dryland Cropping  2.433233e+00
# 2       Black            Forestry  5.595402e+03
# 3       Black    Grazing Forested  3.821115e+04
# 4       Black        Grazing Open  1.116167e+04
# 5       Black        Horticulture  7.857883e+02
# 6       Black  Irrigated Cropping  0.000000e+00
# 7       Black               Other  1.034255e+03
# 8       Black              Stream  0.000000e+00
# 9       Black           Sugarcane  1.203646e+03
# 10      Black       System Supply  0.000000e+00
# 11      Black               Urban  3.431840e+03
# 12      Black               Water  1.997617e+03
# 13   Burdekin        Conservation  6.785578e+05
# 14   Burdekin    Dryland Cropping  1.258077e+05
# 15   Burdekin            Forestry  8.302941e+04
# 16   Burdekin    Grazing Forested  4.660898e+06
# 17   Burdekin        Grazing Open  7.289241e+06
# 18   Burdekin        Horticulture  3.302888e+02
# 19   Burdekin  Irrigated Cropping  5.214953e+03
# 20   Burdekin               Other  1.889009e+04
# 21   Burdekin              Stream  0.000000e+00
# 22   Burdekin           Sugarcane  2.285736e+04
# 23   Burdekin       System Supply  0.000000e+00
# 24   Burdekin               Urban  5.386783e+03

# %%
#regLuseSummary = pd.DataFrame(rawcontrib.groupby(['Rep_Region','Constituent','FU','Process']).agg({'AnnLoadToStreamKG':'sum','AnnLoadToExportKG':'sum'})).reset_index()
regLuseSummary = pd.DataFrame(rawcontrib[rawcontrib['Constituent'].isin(selectedConstituents)].groupby(['Rep_Region','Constituent','FU','Process']).agg({'AnnLoadToStreamKG':'sum','AnnLoadToExportKG':'sum'})).reset_index()
regLuseSummary.head(15)
# Out:
#    Rep_Region    Constituent                FU  \
# 0       Black  N_Particulate      Conservation
# 1       Black  N_Particulate      Conservation
# 2       Black  N_Particulate      Conservation
# 3       Black  N_Particulate      Conservation
# 4       Black  N_Particulate      Conservation
# 5       Black  N_Particulate      Conservation
# 6       Black  N_Particulate      Conservation
# 7       Black  N_Particulate  Dryland Cropping
# 8       Black  N_Particulate  Dryland Cropping
# 9       Black  N_Particulate  Dryland Cropping
# 10      Black  N_Particulate  Dryland Cropping
# 11      Black  N_Particulate  Dryland Cropping
# 12      Black  N_Particulate  Dryland Cropping
# 13      Black  N_Particulate  Dryland Cropping
# 14      Black  N_Particulate          Forestry
#
#                             Process  AnnLoadToExportKG  AnnLoadToStreamKG
# 0                 Diffuse Dissolved           0.000000           0.000000
# 1                             Gully        4134.578688        4265.601338
# 2   Hillslope no source distinction       92609.367595       93931.875242
# 3        Hillslope sub-surface soil           0.000000           0.000000
# 4            Hillslope surface soil           0.000000           0.000000
# 5                           Seepage           0.000000           0.000000
# 6                         Undefined           0.000000           0.000000
# 7                 Diffuse Dissolved           0.000000           0.000000
# 8                             Gully           0.000000           0.000000
# 9   Hillslope no source distinction           5.213517           5.240958
# 10       Hillslope sub-surface soil           0.000000           0.000000
# 11           Hillslope surface soil           0.000000           0.000000
# 12                          Seepage           0.000000           0.000000
# 13                        Undefined           0.000000           0.000000
# 14                Diffuse Dissolved           0.000000           0.000000

# %%
### Join/merge with Regional Areas
regLuseSumPlusArea = pd.merge(regLuseSummary, regFuArea, how='left', left_on=['Rep_Region','FU'], right_on = ['Rep_Region','FU'])
regLuseSumPlusArea.head(15)
# Out:
#    Rep_Region    Constituent                FU  \
# 0       Black  N_Particulate      Conservation
# 1       Black  N_Particulate      Conservation
# 2       Black  N_Particulate      Conservation
# 3       Black  N_Particulate      Conservation
# 4       Black  N_Particulate      Conservation
# 5       Black  N_Particulate      Conservation
# 6       Black  N_Particulate      Conservation
# 7       Black  N_Particulate  Dryland Cropping
# 8       Black  N_Particulate  Dryland Cropping
# 9       Black  N_Particulate  Dryland Cropping
# 10      Black  N_Particulate  Dryland Cropping
# 11      Black  N_Particulate  Dryland Cropping
# 12      Black  N_Particulate  Dryland Cropping
# 13      Black  N_Particulate  Dryland Cropping
# 14      Black  N_Particulate          Forestry
#
#                             Process  AnnLoadToExportKG  AnnLoadToStreamKG  \
# 0                 Diffuse Dissolved           0.000000           0.000000
# 1                             Gully        4134.578688        4265.601338
# 2   Hillslope no source distinction       92609.367595       93931.875242
# 3        Hillslope sub-surface soil           0.000000           0.000000
# 4            Hillslope surface soil           0.000000           0.000000
# 5                           Seepage           0.000000           0.000000
# 6                         Undefined           0.000000           0.000000
# 7                 Diffuse Dissolved           0.000000           0.000000
# 8                             Gully           0.000000           0.000000
# 9   Hillslope no source distinction           5.213517           5.240958
# 10       Hillslope sub-surface soil           0.000000           0.000000
# 11           Hillslope surface soil           0.000000           0.000000
# 12                          Seepage           0.000000           0.000000
# 13                        Undefined           0.000000           0.000000
# 14                Diffuse Dissolved           0.000000           0.000000
#
#           AreaHA
# 0   40628.618620
# 1   40628.618620
# 2   40628.618620
# 3   40628.618620
# 4   40628.618620
# 5   40628.618620
# 6   40628.618620
# 7       2.433233
# 8       2.433233
# 9       2.433233
# 10      2.433233
# 11      2.433233
# 12      2.433233
# 13      2.433233
# 14   5595.402051

# %%
regLuseSumPlusArea.to_csv('D:/test_out_Burd.csv', index=False)
